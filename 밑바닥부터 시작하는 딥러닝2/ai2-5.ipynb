# %% [markdown]
# ![RNN logic](../image/RNN1.png)
#
# matmul
# (A, B) @ (B, C) = (A, C)
#
# +
# (N, H) + (N, H) = (N, H)
# if can use broadcast
# (N, H) + (H,) = (N, H)

# %%
class RNN:
    def __init__(self, Wx, Wh, b):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.cache = None
    
    def forward(self, x, h_prev):
        Wx, Wh, b = self.params
        
        #가중치 연산.
        #shape: (N, H) @ (H, H) + (N, D) @ (D, H) + (H,) = (N, H)
        t = np.matmul(h_prev, Wh) + np.matmul(x, Wx) + b
        
        #tanh 활성함수
        #shape: (N, H)
        h_next = np.tanh(t)
        print
        
        self.cache = (x, h_prev, h_next)
        return h_next
    
    #dh_next Shape: (N, H)
    def backward(self, dh_next):
        Wx, Wh, b = self.params
        
        #x Shape: (N, D)
        #h_prev Shape: (N, H)
        #h_next Shape: (N, H)
        x, h_prev, h_next = self.cache
        
        #tanh 활성함수의 미분
        #dt Shape: (N, H)
        dt = dh_next * (1 - h_next ** 2)
        
        #가중치 연산의 미분
        #db Shape: (H,)
        db = np.sum(dt, axis=0)
        
        #이전 은닉 상태의 미분
        #dWh Shape: (H, N) @ (N, H) = (H, H)
        dWh = np.matmul(h_prev.T, dt)
        
        #입력의 미분
        #dWx Shape: (D, N) @ (N, H) = (D, H)
        dWx = np.matmul(x.T, dt)
        
        #이전 은닉 상태의 미분
        #dh_prev Shape: (N, H) @ (H, H) = (N, H)
        dh_prev = np.matmul(dt, Wh.T)
        
        self.grads[0][...] = dWx
        self.grads[1][...] = dWh
        self.grads[2][...] = db
        
        return dh_prev

# %% [markdown]
# N : Batch Size
#
# T : Time Step Size
#
# D : Input Dimension Size
#
# H : Hidden Dimension Size

# %%
class TimeRNN:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
        
        self.h, self.dh = None, None
        self.stateful = stateful
    
    def set_state(self, h):
        self.h = h
    
    def reset_state(self):
        self.h = None

# %%
class TimeRNN:
    def __init__(self, Wx, Wh, b, stateful=False):
        self.params = [Wx, Wh, b]
        self.grads = [np.zeros_like(Wx), np.zeros_like(Wh), np.zeros_like(b)]
        self.layers = None
        
        self.h, self.dh = None, None
        self.stateful = stateful
    
    def set_state(self, h):
        self.h = h
    
    def reset_state(self):
        self.h = None
    
    #shape: (N, T, D)
    def forward(self, xs):
        #Wx shape: (D, H)
        #Wh shape: (H, H)
        #b shape: (H,)
        Wx, Wh, b = self.params
        
        # 입력 데이터 형상
        N, T, D = xs.shape
        
        # 은닉 상태 형상
        D, H = Wx.shape
        
        self.layers = []
        
        # 은닉 상태 초기화
        # 다음 Time RNN클래스에서 사용할 은닉 상태 변수
        #hs shape: (N, T, H)
        # N개의 데이터, T개의 시간 단계, H개의 은닉 상태
        hs = np.empty((N, T, H), dtype='f')
        
        
        
        # 다음 Time RNN클래스에서 사용한다면 stateful=True로 설정해야 함
        # 또는 초기 호출시 은닉 상태를 초기화해야 함
        if not self.stateful or self.h is None:
            self.h = np.zeros((N, H), dtype='f')
        
        # 시간 차원에 대한 반복
        # RNN1 RNN2 RNN3 순으로 처리
         
        
        # 은닉 상태 반환
        return hs
    
    def backward(self, dhs):
        Wx, Wh, b = self.params
        N, T, H = dhs.shape
        D, H = Wx.shape
        
        # 역전파 시작
        dxs = np.empty((N, T, D), dtype='f')
        dh = 0
        
        grads = [0,0,0]
        
        # 시간 차원에 대한 반복
        # RNN3 RNN2 RNN1 순으로 처리
        for t in reversed(range(T)):
            layer = self.layers[t]
            dx, dh = layer.backward(dhs[:, t, :] + dh)
            dxs[:, t, :] = dx
            
            for i, grad in enumerate(layer.grads):
                grads[i] += grad
            
            dh = dh_next
        
        for i, grad in enumerate(grads):
            self.grads[i] += grad
        
        self.dh = dh
        
        return dxs

# %%
import sys
sys.path.append('./deep/')
import numpy as np
from common.time_layers import *

class SimpleRnnlm:
    def __init__(self, vocab_size, wordvec_size, hidden_size):
        V, D, H = vocab_size, wordvec_size, hidden_size
        rn = np.random.randn
        
        embed_W = (rn(V,D) / 100).astype('f')
        rnn_Wx  = (rn(D,H) / np.sqrt(D)).astype('f')
        rnn_Wh  = (rn(H,H) / np.sqrt(H)).astype('f')
        rnn_b   = np.zeros(H).astype('f')
        
        affine_W = (rn(H,V) / np.sqrt(H)).astype('f')
        affine_b = np.zeros(V).astype('f')
        
        self.layers = [
            TimeEmbedding(embed_W),
            TimeRNN(rnn_Wx, rnn_Wh, rnn_b, stateful=True),
            TimeAffine(affine_W, affine_b)
        ]
        self.loss_layer = TimeSoftmaxWithLoss()
        self.rnn_layer = self.layers[1]
        
        self.params, self.grads = [], []
        for layer in self.layers:
            self.params += layer.params
            self.grads += layer.grads
            
    def forward(self, xs, ts):
        for layer in self.layers:
            xs = layer.forward(xs)
        loss = self.loss_layer.forward(xs, ts)
        return loss
    
    def backward(self, dout=1):
        dout = self.loss_layer.backward(dout)
        for layer in reversed(self.layers):
            dout = layer.backward(dout)
        return dout
    
    def reset_state(self):
        self.rnn_layer.reset_state()

# %%
import sys

sys.path.append('./deep/')

import matplotlib.pyplot as plt
import numpy as np
from common.optimizer import Adam
from dataset import ptb
# from ch05.simple_rnnlm import SimpleRnnlm

from common.util import clip_grads  # 추가

batch_size = 10
wordvec_size = 100
hidden_size = 100
time_size = 5
lr = 0.001
max_epoch = 1000

max_grad = 5.0  # Gradient clipping 추가

corpus, word_to_id, id_to_word = ptb.load_data('train')
corpus_size = 10000

corpus = corpus[:corpus_size]

vocab_size = len(word_to_id)
xs = corpus[:-1]
ts = corpus[1:]
data_size = len(xs)

print('말뭉치 크기: %d, 어휘 수: %d' % (corpus_size, vocab_size))

max_iters = data_size // (batch_size * time_size)
total_loss = 0
loss_count = 0
ppl_list = []

model = SimpleRnnlm(vocab_size, wordvec_size, hidden_size)
optimizer = Adam(lr)

jump = (corpus_size - 1) // batch_size
offsets = [i * jump for i in range(batch_size)]

for epoch in range(max_epoch):
    time_idx = 0  # 에포크마다 리셋
    for iters in range(max_iters):
        # 2D 배열로 초기화
        batch_x = np.empty((batch_size, time_size), dtype='i')
        batch_t = np.empty((batch_size, time_size), dtype='i')
        
        for t in range(time_size):
            for i, offset in enumerate(offsets):
                batch_x[i, t] = xs[(offset + time_idx) % data_size]
                batch_t[i, t] = ts[(offset + time_idx) % data_size]
            time_idx += 1
        
        loss = model.forward(batch_x, batch_t)
        model.backward(dout=1)
        
        if max_grad is not None:
            clip_grads(model.grads, max_grad)
        
        
        optimizer.update(model.params, model.grads)
        total_loss += loss
        loss_count += 1
    
    ppl = np.exp(total_loss / loss_count)
    # print 문 수정
    print('| 에포크 %d | 단어 수 %d | 손실 %f | perplexity %f' % (epoch + 1, data_size, total_loss / loss_count, ppl))
    ppl_list.append(float(ppl))
    total_loss, loss_count = 0, 0
# Out:
# 말뭉치 크기: 10000, 어휘 수: 10000
# | 에포크 1 | 단어 수 9999 | 손실 7.317571 | perplexity 1506.539646
# | 에포크 2 | 단어 수 9999 | 손실 5.972488 | perplexity 392.480824
# | 에포크 3 | 단어 수 9999 | 손실 5.573101 | perplexity 263.249077
# | 에포크 4 | 단어 수 9999 | 손실 5.180556 | perplexity 177.781698
# | 에포크 5 | 단어 수 9999 | 손실 4.790765 | perplexity 120.393400
# | 에포크 6 | 단어 수 9999 | 손실 4.419150 | perplexity 83.025673
# | 에포크 7 | 단어 수 9999 | 손실 4.071925 | perplexity 58.669807
# | 에포크 8 | 단어 수 9999 | 손실 3.735256 | perplexity 41.898750
# | 에포크 9 | 단어 수 9999 | 손실 3.402706 | perplexity 30.045289
# | 에포크 10 | 단어 수 9999 | 손실 3.089447 | perplexity 21.964938
# | 에포크 11 | 단어 수 9999 | 손실 2.794650 | perplexity 16.356896
# | 에포크 12 | 단어 수 9999 | 손실 2.523296 | perplexity 12.469630
# | 에포크 13 | 단어 수 9999 | 손실 2.274477 | perplexity 9.722831
# | 에포크 14 | 단어 수 9999 | 손실 2.045598 | perplexity 7.733781
# | 에포크 15 | 단어 수 9999 | 손실 1.839805 | perplexity 6.295310
# | 에포크 16 | 단어 수 9999 | 손실 1.660145 | perplexity 5.260072
# | 에포크 17 | 단어 수 9999 | 손실 1.499509 | perplexity 4.479490
# | 에포크 18 | 단어 수 9999 | 손실 1.358369 | perplexity 3.889844
# | 에포크 19 | 단어 수 9999 | 손실 1.232947 | perplexity 3.431328
# | 에포크 20 | 단어 수 9999 | 손실 1.123288 | perplexity 3.074948
# | 에포크 21 | 단어 수 9999 | 손실 1.026906 | perplexity 2.792413
# | 에포크 22 | 단어 수 9999 | 손실 0.940017 | perplexity 2.560026
# | 에포크 23 | 단어 수 9999 | 손실 0.864504 | perplexity 2.373827
# | 에포크 24 | 단어 수 9999 | 손실 0.797959 | perplexity 2.221004
# | 에포크 25 | 단어 수 9999 | 손실 0.734805 | perplexity 2.085075
# | 에포크 26 | 단어 수 9999 | 손실 0.680967 | perplexity 1.975788
# | 에포크 27 | 단어 수 9999 | 손실 0.630008 | perplexity 1.877626
# | 에포크 28 | 단어 수 9999 | 손실 0.585279 | perplexity 1.795492
# | 에포크 29 | 단어 수 9999 | 손실 0.544480 | perplexity 1.723712
# | 에포크 30 | 단어 수 9999 | 손실 0.507904 | perplexity 1.661805
# | 에포크 31 | 단어 수 9999 | 손실 0.474316 | perplexity 1.606914
# | 에포크 32 | 단어 수 9999 | 손실 0.444202 | perplexity 1.559246
# | 에포크 33 | 단어 수 9999 | 손실 0.419139 | perplexity 1.520652
# | 에포크 34 | 단어 수 9999 | 손실 0.389944 | perplexity 1.476899
# | 에포크 35 | 단어 수 9999 | 손실 0.365568 | perplexity 1.441332
# | 에포크 36 | 단어 수 9999 | 손실 0.347718 | perplexity 1.415833
# | 에포크 37 | 단어 수 9999 | 손실 0.328174 | perplexity 1.388431
# | 에포크 38 | 단어 수 9999 | 손실 0.311557 | perplexity 1.365549
# | 에포크 39 | 단어 수 9999 | 손실 0.294442 | perplexity 1.342377
# | 에포크 40 | 단어 수 9999 | 손실 0.282085 | perplexity 1.325892
# | 에포크 41 | 단어 수 9999 | 손실 0.262864 | perplexity 1.300649
# | 에포크 42 | 단어 수 9999 | 손실 0.250330 | perplexity 1.284450
# | 에포크 43 | 단어 수 9999 | 손실 0.232538 | perplexity 1.261798
# | 에포크 44 | 단어 수 9999 | 손실 0.225800 | perplexity 1.253326
# | 에포크 45 | 단어 수 9999 | 손실 0.208488 | perplexity 1.231815
# | 에포크 46 | 단어 수 9999 | 손실 0.202954 | perplexity 1.225016
# | 에포크 47 | 단어 수 9999 | 손실 0.191405 | perplexity 1.210950
# | 에포크 48 | 단어 수 9999 | 손실 0.179262 | perplexity 1.196335
# | 에포크 49 | 단어 수 9999 | 손실 0.168514 | perplexity 1.183545
# | 에포크 50 | 단어 수 9999 | 손실 0.157039 | perplexity 1.170041
# | 에포크 51 | 단어 수 9999 | 손실 0.153339 | perplexity 1.165720
# | 에포크 52 | 단어 수 9999 | 손실 0.151337 | perplexity 1.163388
# | 에포크 53 | 단어 수 9999 | 손실 0.145669 | perplexity 1.156813
# | 에포크 54 | 단어 수 9999 | 손실 0.143625 | perplexity 1.154451
# | 에포크 55 | 단어 수 9999 | 손실 0.136157 | perplexity 1.145862
# | 에포크 56 | 단어 수 9999 | 손실 0.126397 | perplexity 1.134732
# | 에포크 57 | 단어 수 9999 | 손실 0.118580 | perplexity 1.125897
# | 에포크 58 | 단어 수 9999 | 손실 0.116767 | perplexity 1.123857
# | 에포크 59 | 단어 수 9999 | 손실 0.113613 | perplexity 1.120319
# | 에포크 60 | 단어 수 9999 | 손실 0.109981 | perplexity 1.116257
# | 에포크 61 | 단어 수 9999 | 손실 0.115620 | perplexity 1.122569
# | 에포크 62 | 단어 수 9999 | 손실 0.111036 | perplexity 1.117436
# | 에포크 63 | 단어 수 9999 | 손실 0.104756 | perplexity 1.110439
# | 에포크 64 | 단어 수 9999 | 손실 0.095663 | perplexity 1.100388
# | 에포크 65 | 단어 수 9999 | 손실 0.089865 | perplexity 1.094027
# | 에포크 66 | 단어 수 9999 | 손실 0.081483 | perplexity 1.084895
# | 에포크 67 | 단어 수 9999 | 손실 0.077159 | perplexity 1.080214
# | 에포크 68 | 단어 수 9999 | 손실 0.078612 | perplexity 1.081785
# | 에포크 69 | 단어 수 9999 | 손실 0.070764 | perplexity 1.073328
# | 에포크 70 | 단어 수 9999 | 손실 0.064139 | perplexity 1.066240
# | 에포크 71 | 단어 수 9999 | 손실 0.060242 | perplexity 1.062094
# | 에포크 72 | 단어 수 9999 | 손실 0.058838 | perplexity 1.060604
# | 에포크 73 | 단어 수 9999 | 손실 0.063836 | perplexity 1.065917
# | 에포크 74 | 단어 수 9999 | 손실 0.067901 | perplexity 1.070260
# | 에포크 75 | 단어 수 9999 | 손실 0.079718 | perplexity 1.082981
# | 에포크 76 | 단어 수 9999 | 손실 0.096230 | perplexity 1.101013
# | 에포크 77 | 단어 수 9999 | 손실 0.084474 | perplexity 1.088145
# | 에포크 78 | 단어 수 9999 | 손실 0.070052 | perplexity 1.072564
# | 에포크 79 | 단어 수 9999 | 손실 0.055979 | perplexity 1.057575
# | 에포크 80 | 단어 수 9999 | 손실 0.047152 | perplexity 1.048282
# | 에포크 81 | 단어 수 9999 | 손실 0.044977 | perplexity 1.046004
# | 에포크 82 | 단어 수 9999 | 손실 0.041920 | perplexity 1.042811
# | 에포크 83 | 단어 수 9999 | 손실 0.038554 | perplexity 1.039307
# | 에포크 84 | 단어 수 9999 | 손실 0.040311 | perplexity 1.041134
# | 에포크 85 | 단어 수 9999 | 손실 0.044641 | perplexity 1.045652
# | 에포크 86 | 단어 수 9999 | 손실 0.059630 | perplexity 1.061444
# | 에포크 87 | 단어 수 9999 | 손실 0.091574 | perplexity 1.095898
# | 에포크 88 | 단어 수 9999 | 손실 0.097183 | perplexity 1.102062
# | 에포크 89 | 단어 수 9999 | 손실 0.086868 | perplexity 1.090753
# | 에포크 90 | 단어 수 9999 | 손실 0.056604 | perplexity 1.058237
# | 에포크 91 | 단어 수 9999 | 손실 0.045329 | perplexity 1.046372
# | 에포크 92 | 단어 수 9999 | 손실 0.030777 | perplexity 1.031256
# | 에포크 93 | 단어 수 9999 | 손실 0.025040 | perplexity 1.025356
# | 에포크 94 | 단어 수 9999 | 손실 0.020506 | perplexity 1.020718
# | 에포크 95 | 단어 수 9999 | 손실 0.018278 | perplexity 1.018446
# | 에포크 96 | 단어 수 9999 | 손실 0.017803 | perplexity 1.017963
# | 에포크 97 | 단어 수 9999 | 손실 0.016640 | perplexity 1.016779
# | 에포크 98 | 단어 수 9999 | 손실 0.016626 | perplexity 1.016765
# | 에포크 99 | 단어 수 9999 | 손실 0.026172 | perplexity 1.026517
# | 에포크 100 | 단어 수 9999 | 손실 0.095507 | perplexity 1.100217
# | 에포크 101 | 단어 수 9999 | 손실 0.150259 | perplexity 1.162136
# | 에포크 102 | 단어 수 9999 | 손실 0.112650 | perplexity 1.119240
# | 에포크 103 | 단어 수 9999 | 손실 0.065683 | perplexity 1.067888
# | 에포크 104 | 단어 수 9999 | 손실 0.040393 | perplexity 1.041220
# | 에포크 105 | 단어 수 9999 | 손실 0.027986 | perplexity 1.028381
# | 에포크 106 | 단어 수 9999 | 손실 0.019859 | perplexity 1.020058
# | 에포크 107 | 단어 수 9999 | 손실 0.016689 | perplexity 1.016829
# | 에포크 108 | 단어 수 9999 | 손실 0.014898 | perplexity 1.015010
# | 에포크 109 | 단어 수 9999 | 손실 0.013246 | perplexity 1.013334
# | 에포크 110 | 단어 수 9999 | 손실 0.013115 | perplexity 1.013202
# | 에포크 111 | 단어 수 9999 | 손실 0.015552 | perplexity 1.015673
# | 에포크 112 | 단어 수 9999 | 손실 0.015805 | perplexity 1.015930
# | 에포크 113 | 단어 수 9999 | 손실 0.020236 | perplexity 1.020442
# | 에포크 114 | 단어 수 9999 | 손실 0.032882 | perplexity 1.033428
# | 에포크 115 | 단어 수 9999 | 손실 0.077051 | perplexity 1.080097
# | 에포크 116 | 단어 수 9999 | 손실 0.123699 | perplexity 1.131675
# | 에포크 117 | 단어 수 9999 | 손실 0.088523 | perplexity 1.092560
# | 에포크 118 | 단어 수 9999 | 손실 0.049980 | perplexity 1.051250
# | 에포크 119 | 단어 수 9999 | 손실 0.034916 | perplexity 1.035533
# | 에포크 120 | 단어 수 9999 | 손실 0.021754 | perplexity 1.021992
# | 에포크 121 | 단어 수 9999 | 손실 0.016483 | perplexity 1.016620
# | 에포크 122 | 단어 수 9999 | 손실 0.013858 | perplexity 1.013954
# | 에포크 123 | 단어 수 9999 | 손실 0.012070 | perplexity 1.012143
# | 에포크 124 | 단어 수 9999 | 손실 0.010860 | perplexity 1.010920
# | 에포크 125 | 단어 수 9999 | 손실 0.011684 | perplexity 1.011752
# | 에포크 126 | 단어 수 9999 | 손실 0.011131 | perplexity 1.011193
# | 에포크 127 | 단어 수 9999 | 손실 0.014478 | perplexity 1.014583
# | 에포크 128 | 단어 수 9999 | 손실 0.042392 | perplexity 1.043303
# | 에포크 129 | 단어 수 9999 | 손실 0.102710 | perplexity 1.108170
# | 에포크 130 | 단어 수 9999 | 손실 0.093361 | perplexity 1.097858
# | 에포크 131 | 단어 수 9999 | 손실 0.067819 | perplexity 1.070171
# | 에포크 132 | 단어 수 9999 | 손실 0.042917 | perplexity 1.043851
# | 에포크 133 | 단어 수 9999 | 손실 0.027427 | perplexity 1.027806
# | 에포크 134 | 단어 수 9999 | 손실 0.019735 | perplexity 1.019931
# | 에포크 135 | 단어 수 9999 | 손실 0.013815 | perplexity 1.013910
# | 에포크 136 | 단어 수 9999 | 손실 0.011266 | perplexity 1.011330
# | 에포크 137 | 단어 수 9999 | 손실 0.010698 | perplexity 1.010755
# | 에포크 138 | 단어 수 9999 | 손실 0.009612 | perplexity 1.009658
# | 에포크 139 | 단어 수 9999 | 손실 0.007772 | perplexity 1.007802
# | 에포크 140 | 단어 수 9999 | 손실 0.007926 | perplexity 1.007957
# | 에포크 141 | 단어 수 9999 | 손실 0.007164 | perplexity 1.007190
# | 에포크 142 | 단어 수 9999 | 손실 0.007492 | perplexity 1.007520
# | 에포크 143 | 단어 수 9999 | 손실 0.006511 | perplexity 1.006532
# | 에포크 144 | 단어 수 9999 | 손실 0.006296 | perplexity 1.006316
# | 에포크 145 | 단어 수 9999 | 손실 0.006473 | perplexity 1.006494
# | 에포크 146 | 단어 수 9999 | 손실 0.011121 | perplexity 1.011183
# | 에포크 147 | 단어 수 9999 | 손실 0.097800 | perplexity 1.102742
# | 에포크 148 | 단어 수 9999 | 손실 0.190122 | perplexity 1.209398
# | 에포크 149 | 단어 수 9999 | 손실 0.097348 | perplexity 1.102244
# | 에포크 150 | 단어 수 9999 | 손실 0.050872 | perplexity 1.052188
# | 에포크 151 | 단어 수 9999 | 손실 0.028033 | perplexity 1.028430
# | 에포크 152 | 단어 수 9999 | 손실 0.019074 | perplexity 1.019257
# | 에포크 153 | 단어 수 9999 | 손실 0.012894 | perplexity 1.012978
# | 에포크 154 | 단어 수 9999 | 손실 0.010383 | perplexity 1.010437
# | 에포크 155 | 단어 수 9999 | 손실 0.008877 | perplexity 1.008917
# | 에포크 156 | 단어 수 9999 | 손실 0.008700 | perplexity 1.008738
# | 에포크 157 | 단어 수 9999 | 손실 0.008581 | perplexity 1.008618
# | 에포크 158 | 단어 수 9999 | 손실 0.009675 | perplexity 1.009722
# | 에포크 159 | 단어 수 9999 | 손실 0.010149 | perplexity 1.010201
# | 에포크 160 | 단어 수 9999 | 손실 0.010024 | perplexity 1.010074
# | 에포크 161 | 단어 수 9999 | 손실 0.009700 | perplexity 1.009747
# | 에포크 162 | 단어 수 9999 | 손실 0.021319 | perplexity 1.021548
# | 에포크 163 | 단어 수 9999 | 손실 0.080113 | perplexity 1.083410
# | 에포크 164 | 단어 수 9999 | 손실 0.119284 | perplexity 1.126690
# | 에포크 165 | 단어 수 9999 | 손실 0.069341 | perplexity 1.071801
# | 에포크 166 | 단어 수 9999 | 손실 0.038539 | perplexity 1.039291
# | 에포크 167 | 단어 수 9999 | 손실 0.023767 | perplexity 1.024052
# | 에포크 168 | 단어 수 9999 | 손실 0.016795 | perplexity 1.016937
# | 에포크 169 | 단어 수 9999 | 손실 0.013694 | perplexity 1.013788
# | 에포크 170 | 단어 수 9999 | 손실 0.010150 | perplexity 1.010202
# | 에포크 171 | 단어 수 9999 | 손실 0.008296 | perplexity 1.008331
# | 에포크 172 | 단어 수 9999 | 손실 0.007105 | perplexity 1.007130
# | 에포크 173 | 단어 수 9999 | 손실 0.006396 | perplexity 1.006416
# | 에포크 174 | 단어 수 9999 | 손실 0.005682 | perplexity 1.005698
# | 에포크 175 | 단어 수 9999 | 손실 0.005287 | perplexity 1.005301
# | 에포크 176 | 단어 수 9999 | 손실 0.004999 | perplexity 1.005012
# | 에포크 177 | 단어 수 9999 | 손실 0.005003 | perplexity 1.005015
# | 에포크 178 | 단어 수 9999 | 손실 0.004790 | perplexity 1.004802
# | 에포크 179 | 단어 수 9999 | 손실 0.004220 | perplexity 1.004229
# | 에포크 180 | 단어 수 9999 | 손실 0.004161 | perplexity 1.004170
# | 에포크 181 | 단어 수 9999 | 손실 0.006074 | perplexity 1.006092
# | 에포크 182 | 단어 수 9999 | 손실 0.074026 | perplexity 1.076835
# | 에포크 183 | 단어 수 9999 | 손실 0.175172 | perplexity 1.191452
# | 에포크 184 | 단어 수 9999 | 손실 0.103311 | perplexity 1.108836
# | 에포크 185 | 단어 수 9999 | 손실 0.046160 | perplexity 1.047242
# | 에포크 186 | 단어 수 9999 | 손실 0.025172 | perplexity 1.025491
# | 에포크 187 | 단어 수 9999 | 손실 0.014591 | perplexity 1.014698
# | 에포크 188 | 단어 수 9999 | 손실 0.013258 | perplexity 1.013346
# | 에포크 189 | 단어 수 9999 | 손실 0.009397 | perplexity 1.009442
# | 에포크 190 | 단어 수 9999 | 손실 0.007509 | perplexity 1.007538
# | 에포크 191 | 단어 수 9999 | 손실 0.006719 | perplexity 1.006742
# | 에포크 192 | 단어 수 9999 | 손실 0.006323 | perplexity 1.006343
# | 에포크 193 | 단어 수 9999 | 손실 0.006101 | perplexity 1.006120
# | 에포크 194 | 단어 수 9999 | 손실 0.005645 | perplexity 1.005661
# | 에포크 195 | 단어 수 9999 | 손실 0.005483 | perplexity 1.005498
# | 에포크 196 | 단어 수 9999 | 손실 0.005616 | perplexity 1.005631
# | 에포크 197 | 단어 수 9999 | 손실 0.005442 | perplexity 1.005457
# | 에포크 198 | 단어 수 9999 | 손실 0.008732 | perplexity 1.008770
# | 에포크 199 | 단어 수 9999 | 손실 0.082279 | perplexity 1.085759
# | 에포크 200 | 단어 수 9999 | 손실 0.138888 | perplexity 1.148995
# | 에포크 201 | 단어 수 9999 | 손실 0.070773 | perplexity 1.073338
# | 에포크 202 | 단어 수 9999 | 손실 0.036105 | perplexity 1.036765
# | 에포크 203 | 단어 수 9999 | 손실 0.027167 | perplexity 1.027539
# | 에포크 204 | 단어 수 9999 | 손실 0.016833 | perplexity 1.016975
# | 에포크 205 | 단어 수 9999 | 손실 0.010589 | perplexity 1.010645
# | 에포크 206 | 단어 수 9999 | 손실 0.008169 | perplexity 1.008202
# | 에포크 207 | 단어 수 9999 | 손실 0.007269 | perplexity 1.007295
# | 에포크 208 | 단어 수 9999 | 손실 0.006928 | perplexity 1.006952
# | 에포크 209 | 단어 수 9999 | 손실 0.007253 | perplexity 1.007279
# | 에포크 210 | 단어 수 9999 | 손실 0.007190 | perplexity 1.007216
# | 에포크 211 | 단어 수 9999 | 손실 0.008271 | perplexity 1.008305
# | 에포크 212 | 단어 수 9999 | 손실 0.010775 | perplexity 1.010833
# | 에포크 213 | 단어 수 9999 | 손실 0.019960 | perplexity 1.020160
# | 에포크 214 | 단어 수 9999 | 손실 0.052602 | perplexity 1.054010
# | 에포크 215 | 단어 수 9999 | 손실 0.084980 | perplexity 1.088695
# | 에포크 216 | 단어 수 9999 | 손실 0.064034 | perplexity 1.066128
# | 에포크 217 | 단어 수 9999 | 손실 0.036123 | perplexity 1.036784
# | 에포크 218 | 단어 수 9999 | 손실 0.021633 | perplexity 1.021868
# | 에포크 219 | 단어 수 9999 | 손실 0.018899 | perplexity 1.019079
# | 에포크 220 | 단어 수 9999 | 손실 0.010337 | perplexity 1.010391
# | 에포크 221 | 단어 수 9999 | 손실 0.009902 | perplexity 1.009951
# | 에포크 222 | 단어 수 9999 | 손실 0.007190 | perplexity 1.007216
# | 에포크 223 | 단어 수 9999 | 손실 0.005723 | perplexity 1.005739
# | 에포크 224 | 단어 수 9999 | 손실 0.004893 | perplexity 1.004905
# | 에포크 225 | 단어 수 9999 | 손실 0.004408 | perplexity 1.004418
# | 에포크 226 | 단어 수 9999 | 손실 0.004079 | perplexity 1.004087
# | 에포크 227 | 단어 수 9999 | 손실 0.003776 | perplexity 1.003783
# | 에포크 228 | 단어 수 9999 | 손실 0.003755 | perplexity 1.003762
# | 에포크 229 | 단어 수 9999 | 손실 0.003540 | perplexity 1.003547
# | 에포크 230 | 단어 수 9999 | 손실 0.003342 | perplexity 1.003348
# | 에포크 231 | 단어 수 9999 | 손실 0.003263 | perplexity 1.003268
# | 에포크 232 | 단어 수 9999 | 손실 0.003464 | perplexity 1.003470
# | 에포크 233 | 단어 수 9999 | 손실 0.003921 | perplexity 1.003929
# | 에포크 234 | 단어 수 9999 | 손실 0.003707 | perplexity 1.003714
# | 에포크 235 | 단어 수 9999 | 손실 0.024136 | perplexity 1.024430
# | 에포크 236 | 단어 수 9999 | 손실 0.197470 | perplexity 1.218316
# | 에포크 237 | 단어 수 9999 | 손실 0.129847 | perplexity 1.138654
# | 에포크 238 | 단어 수 9999 | 손실 0.057319 | perplexity 1.058993
# | 에포크 239 | 단어 수 9999 | 손실 0.030724 | perplexity 1.031201
# | 에포크 240 | 단어 수 9999 | 손실 0.020007 | perplexity 1.020208
# | 에포크 241 | 단어 수 9999 | 손실 0.012483 | perplexity 1.012562
# | 에포크 242 | 단어 수 9999 | 손실 0.009007 | perplexity 1.009047
# | 에포크 243 | 단어 수 9999 | 손실 0.007422 | perplexity 1.007449
# | 에포크 244 | 단어 수 9999 | 손실 0.006468 | perplexity 1.006489
# | 에포크 245 | 단어 수 9999 | 손실 0.005939 | perplexity 1.005957
# | 에포크 246 | 단어 수 9999 | 손실 0.005394 | perplexity 1.005409
# | 에포크 247 | 단어 수 9999 | 손실 0.005008 | perplexity 1.005021
# | 에포크 248 | 단어 수 9999 | 손실 0.004576 | perplexity 1.004586
# | 에포크 249 | 단어 수 9999 | 손실 0.004273 | perplexity 1.004282
# | 에포크 250 | 단어 수 9999 | 손실 0.004259 | perplexity 1.004268
# | 에포크 251 | 단어 수 9999 | 손실 0.004819 | perplexity 1.004830
# | 에포크 252 | 단어 수 9999 | 손실 0.004377 | perplexity 1.004387
# | 에포크 253 | 단어 수 9999 | 손실 0.004222 | perplexity 1.004231
# | 에포크 254 | 단어 수 9999 | 손실 0.004711 | perplexity 1.004722
# | 에포크 255 | 단어 수 9999 | 손실 0.004026 | perplexity 1.004034
# | 에포크 256 | 단어 수 9999 | 손실 0.005569 | perplexity 1.005584
# | 에포크 257 | 단어 수 9999 | 손실 0.087170 | perplexity 1.091082
# | 에포크 258 | 단어 수 9999 | 손실 0.156974 | perplexity 1.169965
# | 에포크 259 | 단어 수 9999 | 손실 0.079706 | perplexity 1.082969
# | 에포크 260 | 단어 수 9999 | 손실 0.042599 | perplexity 1.043519
# | 에포크 261 | 단어 수 9999 | 손실 0.023667 | perplexity 1.023949
# | 에포크 262 | 단어 수 9999 | 손실 0.014045 | perplexity 1.014144
# | 에포크 263 | 단어 수 9999 | 손실 0.009558 | perplexity 1.009604
# | 에포크 264 | 단어 수 9999 | 손실 0.007356 | perplexity 1.007383
# | 에포크 265 | 단어 수 9999 | 손실 0.005833 | perplexity 1.005850
# | 에포크 266 | 단어 수 9999 | 손실 0.005233 | perplexity 1.005246
# | 에포크 267 | 단어 수 9999 | 손실 0.004933 | perplexity 1.004945
# | 에포크 268 | 단어 수 9999 | 손실 0.004742 | perplexity 1.004753
# | 에포크 269 | 단어 수 9999 | 손실 0.004874 | perplexity 1.004886
# | 에포크 270 | 단어 수 9999 | 손실 0.004797 | perplexity 1.004809
# | 에포크 271 | 단어 수 9999 | 손실 0.004830 | perplexity 1.004842
# | 에포크 272 | 단어 수 9999 | 손실 0.004731 | perplexity 1.004743
# | 에포크 273 | 단어 수 9999 | 손실 0.004913 | perplexity 1.004925
# | 에포크 274 | 단어 수 9999 | 손실 0.012371 | perplexity 1.012448
# | 에포크 275 | 단어 수 9999 | 손실 0.070554 | perplexity 1.073103
# | 에포크 276 | 단어 수 9999 | 손실 0.101971 | perplexity 1.107352
# | 에포크 277 | 단어 수 9999 | 손실 0.069180 | perplexity 1.071630
# | 에포크 278 | 단어 수 9999 | 손실 0.042588 | perplexity 1.043508
# | 에포크 279 | 단어 수 9999 | 손실 0.028643 | perplexity 1.029058
# | 에포크 280 | 단어 수 9999 | 손실 0.023677 | perplexity 1.023960
# | 에포크 281 | 단어 수 9999 | 손실 0.016265 | perplexity 1.016398
# | 에포크 282 | 단어 수 9999 | 손실 0.010981 | perplexity 1.011042
# | 에포크 283 | 단어 수 9999 | 손실 0.010161 | perplexity 1.010213
# | 에포크 284 | 단어 수 9999 | 손실 0.006828 | perplexity 1.006851
# | 에포크 285 | 단어 수 9999 | 손실 0.005807 | perplexity 1.005824
# | 에포크 286 | 단어 수 9999 | 손실 0.005600 | perplexity 1.005616
# | 에포크 287 | 단어 수 9999 | 손실 0.004621 | perplexity 1.004632
# | 에포크 288 | 단어 수 9999 | 손실 0.004165 | perplexity 1.004174
# | 에포크 289 | 단어 수 9999 | 손실 0.003552 | perplexity 1.003558
# | 에포크 290 | 단어 수 9999 | 손실 0.003239 | perplexity 1.003245
# | 에포크 291 | 단어 수 9999 | 손실 0.002983 | perplexity 1.002987
# | 에포크 292 | 단어 수 9999 | 손실 0.003019 | perplexity 1.003023
# | 에포크 293 | 단어 수 9999 | 손실 0.004282 | perplexity 1.004291
# | 에포크 294 | 단어 수 9999 | 손실 0.003759 | perplexity 1.003766
# | 에포크 295 | 단어 수 9999 | 손실 0.003579 | perplexity 1.003586
# | 에포크 296 | 단어 수 9999 | 손실 0.004420 | perplexity 1.004430
# | 에포크 297 | 단어 수 9999 | 손실 0.014128 | perplexity 1.014228
# | 에포크 298 | 단어 수 9999 | 손실 0.170508 | perplexity 1.185907
# | 에포크 299 | 단어 수 9999 | 손실 0.134717 | perplexity 1.144212
# | 에포크 300 | 단어 수 9999 | 손실 0.057334 | perplexity 1.059009
# | 에포크 301 | 단어 수 9999 | 손실 0.032504 | perplexity 1.033038
# | 에포크 302 | 단어 수 9999 | 손실 0.018612 | perplexity 1.018786
# | 에포크 303 | 단어 수 9999 | 손실 0.014994 | perplexity 1.015107
# | 에포크 304 | 단어 수 9999 | 손실 0.010988 | perplexity 1.011048
# | 에포크 305 | 단어 수 9999 | 손실 0.009361 | perplexity 1.009405
# | 에포크 306 | 단어 수 9999 | 손실 0.008431 | perplexity 1.008467
# | 에포크 307 | 단어 수 9999 | 손실 0.006994 | perplexity 1.007019
# | 에포크 308 | 단어 수 9999 | 손실 0.006129 | perplexity 1.006147
# | 에포크 309 | 단어 수 9999 | 손실 0.006233 | perplexity 1.006253
# | 에포크 310 | 단어 수 9999 | 손실 0.006685 | perplexity 1.006707
# | 에포크 311 | 단어 수 9999 | 손실 0.008636 | perplexity 1.008673
# | 에포크 312 | 단어 수 9999 | 손실 0.014265 | perplexity 1.014367
# | 에포크 313 | 단어 수 9999 | 손실 0.032028 | perplexity 1.032546
# | 에포크 314 | 단어 수 9999 | 손실 0.067460 | perplexity 1.069787
# | 에포크 315 | 단어 수 9999 | 손실 0.080005 | perplexity 1.083293
# | 에포크 316 | 단어 수 9999 | 손실 0.044600 | perplexity 1.045609
# | 에포크 317 | 단어 수 9999 | 손실 0.021541 | perplexity 1.021775
# | 에포크 318 | 단어 수 9999 | 손실 0.012728 | perplexity 1.012810
# | 에포크 319 | 단어 수 9999 | 손실 0.009399 | perplexity 1.009443
# | 에포크 320 | 단어 수 9999 | 손실 0.007452 | perplexity 1.007480
# | 에포크 321 | 단어 수 9999 | 손실 0.006484 | perplexity 1.006505
# | 에포크 322 | 단어 수 9999 | 손실 0.008699 | perplexity 1.008736
# | 에포크 323 | 단어 수 9999 | 손실 0.008245 | perplexity 1.008279
# | 에포크 324 | 단어 수 9999 | 손실 0.007949 | perplexity 1.007981
# | 에포크 325 | 단어 수 9999 | 손실 0.010263 | perplexity 1.010316
# | 에포크 326 | 단어 수 9999 | 손실 0.014061 | perplexity 1.014160
# | 에포크 327 | 단어 수 9999 | 손실 0.022351 | perplexity 1.022603
# | 에포크 328 | 단어 수 9999 | 손실 0.046853 | perplexity 1.047968
# | 에포크 329 | 단어 수 9999 | 손실 0.060981 | perplexity 1.062879
# | 에포크 330 | 단어 수 9999 | 손실 0.053478 | perplexity 1.054934
# | 에포크 331 | 단어 수 9999 | 손실 0.034303 | perplexity 1.034898
# | 에포크 332 | 단어 수 9999 | 손실 0.021961 | perplexity 1.022204
# | 에포크 333 | 단어 수 9999 | 손실 0.013773 | perplexity 1.013868
# | 에포크 334 | 단어 수 9999 | 손실 0.008437 | perplexity 1.008473
# | 에포크 335 | 단어 수 9999 | 손실 0.006569 | perplexity 1.006591
# | 에포크 336 | 단어 수 9999 | 손실 0.005606 | perplexity 1.005621
# | 에포크 337 | 단어 수 9999 | 손실 0.005179 | perplexity 1.005192
# | 에포크 338 | 단어 수 9999 | 손실 0.004433 | perplexity 1.004443
# | 에포크 339 | 단어 수 9999 | 손실 0.004270 | perplexity 1.004279
# | 에포크 340 | 단어 수 9999 | 손실 0.004167 | perplexity 1.004176
# | 에포크 341 | 단어 수 9999 | 손실 0.004049 | perplexity 1.004057
# | 에포크 342 | 단어 수 9999 | 손실 0.003941 | perplexity 1.003949
# | 에포크 343 | 단어 수 9999 | 손실 0.004500 | perplexity 1.004510
# | 에포크 344 | 단어 수 9999 | 손실 0.011886 | perplexity 1.011957
# | 에포크 345 | 단어 수 9999 | 손실 0.083898 | perplexity 1.087518
# | 에포크 346 | 단어 수 9999 | 손실 0.111555 | perplexity 1.118016
# | 에포크 347 | 단어 수 9999 | 손실 0.059186 | perplexity 1.060973
# | 에포크 348 | 단어 수 9999 | 손실 0.035464 | perplexity 1.036101
# | 에포크 349 | 단어 수 9999 | 손실 0.017464 | perplexity 1.017617
# | 에포크 350 | 단어 수 9999 | 손실 0.011200 | perplexity 1.011263
# | 에포크 351 | 단어 수 9999 | 손실 0.008478 | perplexity 1.008514
# | 에포크 352 | 단어 수 9999 | 손실 0.006551 | perplexity 1.006573
# | 에포크 353 | 단어 수 9999 | 손실 0.005255 | perplexity 1.005269
# | 에포크 354 | 단어 수 9999 | 손실 0.005214 | perplexity 1.005227
# | 에포크 355 | 단어 수 9999 | 손실 0.004851 | perplexity 1.004862
# | 에포크 356 | 단어 수 9999 | 손실 0.004854 | perplexity 1.004866
# | 에포크 357 | 단어 수 9999 | 손실 0.005503 | perplexity 1.005518
# | 에포크 358 | 단어 수 9999 | 손실 0.005399 | perplexity 1.005413
# | 에포크 359 | 단어 수 9999 | 손실 0.005786 | perplexity 1.005802
# | 에포크 360 | 단어 수 9999 | 손실 0.006794 | perplexity 1.006817
# | 에포크 361 | 단어 수 9999 | 손실 0.037812 | perplexity 1.038536
# | 에포크 362 | 단어 수 9999 | 손실 0.083047 | perplexity 1.086593
# | 에포크 363 | 단어 수 9999 | 손실 0.073289 | perplexity 1.076041
# | 에포크 364 | 단어 수 9999 | 손실 0.036938 | perplexity 1.037629
# | 에포크 365 | 단어 수 9999 | 손실 0.023106 | perplexity 1.023375
# | 에포크 366 | 단어 수 9999 | 손실 0.013599 | perplexity 1.013692
# | 에포크 367 | 단어 수 9999 | 손실 0.010359 | perplexity 1.010413
# | 에포크 368 | 단어 수 9999 | 손실 0.009080 | perplexity 1.009122
# | 에포크 369 | 단어 수 9999 | 손실 0.007117 | perplexity 1.007142
# | 에포크 370 | 단어 수 9999 | 손실 0.007697 | perplexity 1.007727
# | 에포크 371 | 단어 수 9999 | 손실 0.008550 | perplexity 1.008587
# | 에포크 372 | 단어 수 9999 | 손실 0.008289 | perplexity 1.008324
# | 에포크 373 | 단어 수 9999 | 손실 0.011704 | perplexity 1.011772
# | 에포크 374 | 단어 수 9999 | 손실 0.015359 | perplexity 1.015477
# | 에포크 375 | 단어 수 9999 | 손실 0.029003 | perplexity 1.029428
# | 에포크 376 | 단어 수 9999 | 손실 0.043448 | perplexity 1.044406
# | 에포크 377 | 단어 수 9999 | 손실 0.038694 | perplexity 1.039453
# | 에포크 378 | 단어 수 9999 | 손실 0.027911 | perplexity 1.028304
# | 에포크 379 | 단어 수 9999 | 손실 0.018281 | perplexity 1.018449
# | 에포크 380 | 단어 수 9999 | 손실 0.013218 | perplexity 1.013305
# | 에포크 381 | 단어 수 9999 | 손실 0.008555 | perplexity 1.008592
# | 에포크 382 | 단어 수 9999 | 손실 0.006056 | perplexity 1.006074
# | 에포크 383 | 단어 수 9999 | 손실 0.004612 | perplexity 1.004623
# | 에포크 384 | 단어 수 9999 | 손실 0.004511 | perplexity 1.004521
# | 에포크 385 | 단어 수 9999 | 손실 0.005003 | perplexity 1.005016
# | 에포크 386 | 단어 수 9999 | 손실 0.004739 | perplexity 1.004750
# | 에포크 387 | 단어 수 9999 | 손실 0.004429 | perplexity 1.004439
# | 에포크 388 | 단어 수 9999 | 손실 0.004160 | perplexity 1.004168
# | 에포크 389 | 단어 수 9999 | 손실 0.008432 | perplexity 1.008468
# | 에포크 390 | 단어 수 9999 | 손실 0.051946 | perplexity 1.053319
# | 에포크 391 | 단어 수 9999 | 손실 0.092677 | perplexity 1.097107
# | 에포크 392 | 단어 수 9999 | 손실 0.064437 | perplexity 1.066559
# | 에포크 393 | 단어 수 9999 | 손실 0.031656 | perplexity 1.032162
# | 에포크 394 | 단어 수 9999 | 손실 0.023777 | perplexity 1.024062
# | 에포크 395 | 단어 수 9999 | 손실 0.014569 | perplexity 1.014676
# | 에포크 396 | 단어 수 9999 | 손실 0.009822 | perplexity 1.009870
# | 에포크 397 | 단어 수 9999 | 손실 0.007310 | perplexity 1.007337
# | 에포크 398 | 단어 수 9999 | 손실 0.005720 | perplexity 1.005737
# | 에포크 399 | 단어 수 9999 | 손실 0.005329 | perplexity 1.005343
# | 에포크 400 | 단어 수 9999 | 손실 0.004458 | perplexity 1.004468
# | 에포크 401 | 단어 수 9999 | 손실 0.004400 | perplexity 1.004410
# | 에포크 402 | 단어 수 9999 | 손실 0.009043 | perplexity 1.009084
# | 에포크 403 | 단어 수 9999 | 손실 0.021846 | perplexity 1.022087
# | 에포크 404 | 단어 수 9999 | 손실 0.028375 | perplexity 1.028781
# | 에포크 405 | 단어 수 9999 | 손실 0.033345 | perplexity 1.033907
# | 에포크 406 | 단어 수 9999 | 손실 0.035553 | perplexity 1.036192
# | 에포크 407 | 단어 수 9999 | 손실 0.027608 | perplexity 1.027993
# | 에포크 408 | 단어 수 9999 | 손실 0.016410 | perplexity 1.016546
# | 에포크 409 | 단어 수 9999 | 손실 0.013481 | perplexity 1.013572
# | 에포크 410 | 단어 수 9999 | 손실 0.009340 | perplexity 1.009384
# | 에포크 411 | 단어 수 9999 | 손실 0.006450 | perplexity 1.006471
# | 에포크 412 | 단어 수 9999 | 손실 0.004875 | perplexity 1.004887
# | 에포크 413 | 단어 수 9999 | 손실 0.005450 | perplexity 1.005465
# | 에포크 414 | 단어 수 9999 | 손실 0.004364 | perplexity 1.004373
# | 에포크 415 | 단어 수 9999 | 손실 0.003879 | perplexity 1.003887
# | 에포크 416 | 단어 수 9999 | 손실 0.004287 | perplexity 1.004296
# | 에포크 417 | 단어 수 9999 | 손실 0.005571 | perplexity 1.005587
# | 에포크 418 | 단어 수 9999 | 손실 0.025080 | perplexity 1.025397
# | 에포크 419 | 단어 수 9999 | 손실 0.067598 | perplexity 1.069935
# | 에포크 420 | 단어 수 9999 | 손실 0.069986 | perplexity 1.072493
# | 에포크 421 | 단어 수 9999 | 손실 0.043187 | perplexity 1.044134
# | 에포크 422 | 단어 수 9999 | 손실 0.030570 | perplexity 1.031042
# | 에포크 423 | 단어 수 9999 | 손실 0.018313 | perplexity 1.018482
# | 에포크 424 | 단어 수 9999 | 손실 0.009595 | perplexity 1.009641
# | 에포크 425 | 단어 수 9999 | 손실 0.006707 | perplexity 1.006729
# | 에포크 426 | 단어 수 9999 | 손실 0.005489 | perplexity 1.005504
# | 에포크 427 | 단어 수 9999 | 손실 0.004880 | perplexity 1.004892
# | 에포크 428 | 단어 수 9999 | 손실 0.004730 | perplexity 1.004741
# | 에포크 429 | 단어 수 9999 | 손실 0.004862 | perplexity 1.004874
# | 에포크 430 | 단어 수 9999 | 손실 0.003894 | perplexity 1.003902
# | 에포크 431 | 단어 수 9999 | 손실 0.003837 | perplexity 1.003844
# | 에포크 432 | 단어 수 9999 | 손실 0.004114 | perplexity 1.004122
# | 에포크 433 | 단어 수 9999 | 손실 0.003646 | perplexity 1.003652
# | 에포크 434 | 단어 수 9999 | 손실 0.003440 | perplexity 1.003446
# | 에포크 435 | 단어 수 9999 | 손실 0.003124 | perplexity 1.003129
# | 에포크 436 | 단어 수 9999 | 손실 0.003994 | perplexity 1.004002
# | 에포크 437 | 단어 수 9999 | 손실 0.006478 | perplexity 1.006499
# | 에포크 438 | 단어 수 9999 | 손실 0.084452 | perplexity 1.088120
# | 에포크 439 | 단어 수 9999 | 손실 0.107498 | perplexity 1.113488
# | 에포크 440 | 단어 수 9999 | 손실 0.058996 | perplexity 1.060771
# | 에포크 441 | 단어 수 9999 | 손실 0.030135 | perplexity 1.030593
# | 에포크 442 | 단어 수 9999 | 손실 0.016770 | perplexity 1.016912
# | 에포크 443 | 단어 수 9999 | 손실 0.010434 | perplexity 1.010488
# | 에포크 444 | 단어 수 9999 | 손실 0.007423 | perplexity 1.007451
# | 에포크 445 | 단어 수 9999 | 손실 0.005727 | perplexity 1.005744
# | 에포크 446 | 단어 수 9999 | 손실 0.005207 | perplexity 1.005221
# | 에포크 447 | 단어 수 9999 | 손실 0.004988 | perplexity 1.005000
# | 에포크 448 | 단어 수 9999 | 손실 0.004481 | perplexity 1.004492
# | 에포크 449 | 단어 수 9999 | 손실 0.005205 | perplexity 1.005219
# | 에포크 450 | 단어 수 9999 | 손실 0.006753 | perplexity 1.006776
# | 에포크 451 | 단어 수 9999 | 손실 0.013611 | perplexity 1.013704
# | 에포크 452 | 단어 수 9999 | 손실 0.016283 | perplexity 1.016417
# | 에포크 453 | 단어 수 9999 | 손실 0.025532 | perplexity 1.025861
# | 에포크 454 | 단어 수 9999 | 손실 0.032406 | perplexity 1.032937
# | 에포크 455 | 단어 수 9999 | 손실 0.039147 | perplexity 1.039923
# | 에포크 456 | 단어 수 9999 | 손실 0.033957 | perplexity 1.034540
# | 에포크 457 | 단어 수 9999 | 손실 0.034237 | perplexity 1.034830
# | 에포크 458 | 단어 수 9999 | 손실 0.025915 | perplexity 1.026253
# | 에포크 459 | 단어 수 9999 | 손실 0.016842 | perplexity 1.016984
# | 에포크 460 | 단어 수 9999 | 손실 0.010738 | perplexity 1.010796
# | 에포크 461 | 단어 수 9999 | 손실 0.010532 | perplexity 1.010587
# | 에포크 462 | 단어 수 9999 | 손실 0.010713 | perplexity 1.010771
# | 에포크 463 | 단어 수 9999 | 손실 0.007572 | perplexity 1.007601
# | 에포크 464 | 단어 수 9999 | 손실 0.005760 | perplexity 1.005777
# | 에포크 465 | 단어 수 9999 | 손실 0.005537 | perplexity 1.005553
# | 에포크 466 | 단어 수 9999 | 손실 0.005330 | perplexity 1.005344
# | 에포크 467 | 단어 수 9999 | 손실 0.006387 | perplexity 1.006408
# | 에포크 468 | 단어 수 9999 | 손실 0.007602 | perplexity 1.007630
# | 에포크 469 | 단어 수 9999 | 손실 0.007694 | perplexity 1.007724
# | 에포크 470 | 단어 수 9999 | 손실 0.013818 | perplexity 1.013914
# | 에포크 471 | 단어 수 9999 | 손실 0.035492 | perplexity 1.036129
# | 에포크 472 | 단어 수 9999 | 손실 0.080219 | perplexity 1.083525
# | 에포크 473 | 단어 수 9999 | 손실 0.064758 | perplexity 1.066901
# | 에포크 474 | 단어 수 9999 | 손실 0.040281 | perplexity 1.041103
# | 에포크 475 | 단어 수 9999 | 손실 0.019935 | perplexity 1.020135
# | 에포크 476 | 단어 수 9999 | 손실 0.011324 | perplexity 1.011388
# | 에포크 477 | 단어 수 9999 | 손실 0.008110 | perplexity 1.008143
# | 에포크 478 | 단어 수 9999 | 손실 0.006522 | perplexity 1.006543
# | 에포크 479 | 단어 수 9999 | 손실 0.006030 | perplexity 1.006048
# | 에포크 480 | 단어 수 9999 | 손실 0.006353 | perplexity 1.006373
# | 에포크 481 | 단어 수 9999 | 손실 0.005808 | perplexity 1.005825
# | 에포크 482 | 단어 수 9999 | 손실 0.005665 | perplexity 1.005681
# | 에포크 483 | 단어 수 9999 | 손실 0.005648 | perplexity 1.005664
# | 에포크 484 | 단어 수 9999 | 손실 0.004725 | perplexity 1.004736
# | 에포크 485 | 단어 수 9999 | 손실 0.004058 | perplexity 1.004066
# | 에포크 486 | 단어 수 9999 | 손실 0.003619 | perplexity 1.003625
# | 에포크 487 | 단어 수 9999 | 손실 0.004071 | perplexity 1.004080
# | 에포크 488 | 단어 수 9999 | 손실 0.004613 | perplexity 1.004624
# | 에포크 489 | 단어 수 9999 | 손실 0.005834 | perplexity 1.005851
# | 에포크 490 | 단어 수 9999 | 손실 0.031940 | perplexity 1.032455
# | 에포크 491 | 단어 수 9999 | 손실 0.120538 | perplexity 1.128103
# | 에포크 492 | 단어 수 9999 | 손실 0.077038 | perplexity 1.080083
# | 에포크 493 | 단어 수 9999 | 손실 0.041103 | perplexity 1.041959
# | 에포크 494 | 단어 수 9999 | 손실 0.021580 | perplexity 1.021815
# | 에포크 495 | 단어 수 9999 | 손실 0.018080 | perplexity 1.018244
# | 에포크 496 | 단어 수 9999 | 손실 0.013227 | perplexity 1.013315
# | 에포크 497 | 단어 수 9999 | 손실 0.007992 | perplexity 1.008024
# | 에포크 498 | 단어 수 9999 | 손실 0.005820 | perplexity 1.005837
# | 에포크 499 | 단어 수 9999 | 손실 0.004592 | perplexity 1.004603
# | 에포크 500 | 단어 수 9999 | 손실 0.004153 | perplexity 1.004161
# | 에포크 501 | 단어 수 9999 | 손실 0.003830 | perplexity 1.003837
# | 에포크 502 | 단어 수 9999 | 손실 0.004367 | perplexity 1.004377
# | 에포크 503 | 단어 수 9999 | 손실 0.004627 | perplexity 1.004638
# | 에포크 504 | 단어 수 9999 | 손실 0.004351 | perplexity 1.004361
# | 에포크 505 | 단어 수 9999 | 손실 0.005192 | perplexity 1.005205
# | 에포크 506 | 단어 수 9999 | 손실 0.010380 | perplexity 1.010434
# | 에포크 507 | 단어 수 9999 | 손실 0.021636 | perplexity 1.021872
# | 에포크 508 | 단어 수 9999 | 손실 0.046999 | perplexity 1.048121
# | 에포크 509 | 단어 수 9999 | 손실 0.070975 | perplexity 1.073554
# | 에포크 510 | 단어 수 9999 | 손실 0.046808 | perplexity 1.047920
# | 에포크 511 | 단어 수 9999 | 손실 0.026614 | perplexity 1.026971
# | 에포크 512 | 단어 수 9999 | 손실 0.015768 | perplexity 1.015893
# | 에포크 513 | 단어 수 9999 | 손실 0.009210 | perplexity 1.009253
# | 에포크 514 | 단어 수 9999 | 손실 0.007265 | perplexity 1.007292
# | 에포크 515 | 단어 수 9999 | 손실 0.005253 | perplexity 1.005266
# | 에포크 516 | 단어 수 9999 | 손실 0.004970 | perplexity 1.004982
# | 에포크 517 | 단어 수 9999 | 손실 0.005421 | perplexity 1.005436
# | 에포크 518 | 단어 수 9999 | 손실 0.005977 | perplexity 1.005995
# | 에포크 519 | 단어 수 9999 | 손실 0.005037 | perplexity 1.005050
# | 에포크 520 | 단어 수 9999 | 손실 0.005698 | perplexity 1.005714
# | 에포크 521 | 단어 수 9999 | 손실 0.004147 | perplexity 1.004155
# | 에포크 522 | 단어 수 9999 | 손실 0.004738 | perplexity 1.004749
# | 에포크 523 | 단어 수 9999 | 손실 0.006647 | perplexity 1.006669
# | 에포크 524 | 단어 수 9999 | 손실 0.016498 | perplexity 1.016635
# | 에포크 525 | 단어 수 9999 | 손실 0.052186 | perplexity 1.053572
# | 에포크 526 | 단어 수 9999 | 손실 0.077375 | perplexity 1.080447
# | 에포크 527 | 단어 수 9999 | 손실 0.051509 | perplexity 1.052859
# | 에포크 528 | 단어 수 9999 | 손실 0.031244 | perplexity 1.031738
# | 에포크 529 | 단어 수 9999 | 손실 0.021230 | perplexity 1.021457
# | 에포크 530 | 단어 수 9999 | 손실 0.012290 | perplexity 1.012366
# | 에포크 531 | 단어 수 9999 | 손실 0.008532 | perplexity 1.008569
# | 에포크 532 | 단어 수 9999 | 손실 0.005888 | perplexity 1.005906
# | 에포크 533 | 단어 수 9999 | 손실 0.004585 | perplexity 1.004596
# | 에포크 534 | 단어 수 9999 | 손실 0.004152 | perplexity 1.004161
# | 에포크 535 | 단어 수 9999 | 손실 0.003778 | perplexity 1.003785
# | 에포크 536 | 단어 수 9999 | 손실 0.003517 | perplexity 1.003523
# | 에포크 537 | 단어 수 9999 | 손실 0.003309 | perplexity 1.003315
# | 에포크 538 | 단어 수 9999 | 손실 0.003159 | perplexity 1.003164
# | 에포크 539 | 단어 수 9999 | 손실 0.003147 | perplexity 1.003152
# | 에포크 540 | 단어 수 9999 | 손실 0.004669 | perplexity 1.004680
# | 에포크 541 | 단어 수 9999 | 손실 0.006901 | perplexity 1.006925
# | 에포크 542 | 단어 수 9999 | 손실 0.028696 | perplexity 1.029111
# | 에포크 543 | 단어 수 9999 | 손실 0.090919 | perplexity 1.095181
# | 에포크 544 | 단어 수 9999 | 손실 0.078458 | perplexity 1.081618
# | 에포크 545 | 단어 수 9999 | 손실 0.041105 | perplexity 1.041962
# | 에포크 546 | 단어 수 9999 | 손실 0.022984 | perplexity 1.023250
# | 에포크 547 | 단어 수 9999 | 손실 0.015269 | perplexity 1.015386
# | 에포크 548 | 단어 수 9999 | 손실 0.007161 | perplexity 1.007187
# | 에포크 549 | 단어 수 9999 | 손실 0.004900 | perplexity 1.004912
# | 에포크 550 | 단어 수 9999 | 손실 0.004157 | perplexity 1.004166
# | 에포크 551 | 단어 수 9999 | 손실 0.003837 | perplexity 1.003844
# | 에포크 552 | 단어 수 9999 | 손실 0.003352 | perplexity 1.003357
# | 에포크 553 | 단어 수 9999 | 손실 0.003206 | perplexity 1.003211
# | 에포크 554 | 단어 수 9999 | 손실 0.003200 | perplexity 1.003205
# | 에포크 555 | 단어 수 9999 | 손실 0.003629 | perplexity 1.003636
# | 에포크 556 | 단어 수 9999 | 손실 0.004650 | perplexity 1.004661
# | 에포크 557 | 단어 수 9999 | 손실 0.005824 | perplexity 1.005841
# | 에포크 558 | 단어 수 9999 | 손실 0.010573 | perplexity 1.010629
# | 에포크 559 | 단어 수 9999 | 손실 0.039226 | perplexity 1.040005
# | 에포크 560 | 단어 수 9999 | 손실 0.073559 | perplexity 1.076333
# | 에포크 561 | 단어 수 9999 | 손실 0.057790 | perplexity 1.059492
# | 에포크 562 | 단어 수 9999 | 손실 0.038571 | perplexity 1.039325
# | 에포크 563 | 단어 수 9999 | 손실 0.023919 | perplexity 1.024208
# | 에포크 564 | 단어 수 9999 | 손실 0.015295 | perplexity 1.015412
# | 에포크 565 | 단어 수 9999 | 손실 0.016102 | perplexity 1.016232
# | 에포크 566 | 단어 수 9999 | 손실 0.010219 | perplexity 1.010271
# | 에포크 567 | 단어 수 9999 | 손실 0.008492 | perplexity 1.008528
# | 에포크 568 | 단어 수 9999 | 손실 0.007482 | perplexity 1.007511
# | 에포크 569 | 단어 수 9999 | 손실 0.005892 | perplexity 1.005910
# | 에포크 570 | 단어 수 9999 | 손실 0.004868 | perplexity 1.004880
# | 에포크 571 | 단어 수 9999 | 손실 0.005575 | perplexity 1.005590
# | 에포크 572 | 단어 수 9999 | 손실 0.006180 | perplexity 1.006199
# | 에포크 573 | 단어 수 9999 | 손실 0.008555 | perplexity 1.008592
# | 에포크 574 | 단어 수 9999 | 손실 0.015646 | perplexity 1.015769
# | 에포크 575 | 단어 수 9999 | 손실 0.020546 | perplexity 1.020758
# | 에포크 576 | 단어 수 9999 | 손실 0.045792 | perplexity 1.046856
# | 에포크 577 | 단어 수 9999 | 손실 0.053881 | perplexity 1.055359
# | 에포크 578 | 단어 수 9999 | 손실 0.037133 | perplexity 1.037831
# | 에포크 579 | 단어 수 9999 | 손실 0.029267 | perplexity 1.029700
# | 에포크 580 | 단어 수 9999 | 손실 0.015715 | perplexity 1.015839
# | 에포크 581 | 단어 수 9999 | 손실 0.015587 | perplexity 1.015709
# | 에포크 582 | 단어 수 9999 | 손실 0.011204 | perplexity 1.011267
# | 에포크 583 | 단어 수 9999 | 손실 0.007806 | perplexity 1.007837
# | 에포크 584 | 단어 수 9999 | 손실 0.006239 | perplexity 1.006259
# | 에포크 585 | 단어 수 9999 | 손실 0.005644 | perplexity 1.005660
# | 에포크 586 | 단어 수 9999 | 손실 0.004262 | perplexity 1.004271
# | 에포크 587 | 단어 수 9999 | 손실 0.004145 | perplexity 1.004153
# | 에포크 588 | 단어 수 9999 | 손실 0.003223 | perplexity 1.003228
# | 에포크 589 | 단어 수 9999 | 손실 0.003279 | perplexity 1.003284
# | 에포크 590 | 단어 수 9999 | 손실 0.003376 | perplexity 1.003382
# | 에포크 591 | 단어 수 9999 | 손실 0.003455 | perplexity 1.003461
# | 에포크 592 | 단어 수 9999 | 손실 0.003016 | perplexity 1.003020
# | 에포크 593 | 단어 수 9999 | 손실 0.003325 | perplexity 1.003331
# | 에포크 594 | 단어 수 9999 | 손실 0.003087 | perplexity 1.003092
# | 에포크 595 | 단어 수 9999 | 손실 0.003174 | perplexity 1.003179
# | 에포크 596 | 단어 수 9999 | 손실 0.003032 | perplexity 1.003036
# | 에포크 597 | 단어 수 9999 | 손실 0.002799 | perplexity 1.002803
# | 에포크 598 | 단어 수 9999 | 손실 0.002899 | perplexity 1.002903
# | 에포크 599 | 단어 수 9999 | 손실 0.005212 | perplexity 1.005225
# | 에포크 600 | 단어 수 9999 | 손실 0.112399 | perplexity 1.118959
# | 에포크 601 | 단어 수 9999 | 손실 0.137397 | perplexity 1.147284
# | 에포크 602 | 단어 수 9999 | 손실 0.062498 | perplexity 1.064492
# | 에포크 603 | 단어 수 9999 | 손실 0.029732 | perplexity 1.030179
# | 에포크 604 | 단어 수 9999 | 손실 0.016487 | perplexity 1.016624
# | 에포크 605 | 단어 수 9999 | 손실 0.011287 | perplexity 1.011351
# | 에포크 606 | 단어 수 9999 | 손실 0.007658 | perplexity 1.007687
# | 에포크 607 | 단어 수 9999 | 손실 0.006343 | perplexity 1.006363
# | 에포크 608 | 단어 수 9999 | 손실 0.005114 | perplexity 1.005127
# | 에포크 609 | 단어 수 9999 | 손실 0.003816 | perplexity 1.003823
# | 에포크 610 | 단어 수 9999 | 손실 0.004029 | perplexity 1.004037
# | 에포크 611 | 단어 수 9999 | 손실 0.004152 | perplexity 1.004160
# | 에포크 612 | 단어 수 9999 | 손실 0.007608 | perplexity 1.007637
# | 에포크 613 | 단어 수 9999 | 손실 0.009998 | perplexity 1.010048
# | 에포크 614 | 단어 수 9999 | 손실 0.009373 | perplexity 1.009417
# | 에포크 615 | 단어 수 9999 | 손실 0.011997 | perplexity 1.012070
# | 에포크 616 | 단어 수 9999 | 손실 0.016675 | perplexity 1.016814
# | 에포크 617 | 단어 수 9999 | 손실 0.042228 | perplexity 1.043133
# | 에포크 618 | 단어 수 9999 | 손실 0.047219 | perplexity 1.048351
# | 에포크 619 | 단어 수 9999 | 손실 0.036616 | perplexity 1.037295
# | 에포크 620 | 단어 수 9999 | 손실 0.024513 | perplexity 1.024816
# | 에포크 621 | 단어 수 9999 | 손실 0.013825 | perplexity 1.013921
# | 에포크 622 | 단어 수 9999 | 손실 0.008979 | perplexity 1.009019
# | 에포크 623 | 단어 수 9999 | 손실 0.005846 | perplexity 1.005863
# | 에포크 624 | 단어 수 9999 | 손실 0.005461 | perplexity 1.005476
# | 에포크 625 | 단어 수 9999 | 손실 0.004501 | perplexity 1.004511
# | 에포크 626 | 단어 수 9999 | 손실 0.005729 | perplexity 1.005746
# | 에포크 627 | 단어 수 9999 | 손실 0.007061 | perplexity 1.007086
# | 에포크 628 | 단어 수 9999 | 손실 0.008645 | perplexity 1.008683
# | 에포크 629 | 단어 수 9999 | 손실 0.014315 | perplexity 1.014418
# | 에포크 630 | 단어 수 9999 | 손실 0.026884 | perplexity 1.027248
# | 에포크 631 | 단어 수 9999 | 손실 0.037335 | perplexity 1.038040
# | 에포크 632 | 단어 수 9999 | 손실 0.033414 | perplexity 1.033979
# | 에포크 633 | 단어 수 9999 | 손실 0.022871 | perplexity 1.023134
# | 에포크 634 | 단어 수 9999 | 손실 0.021508 | perplexity 1.021741
# | 에포크 635 | 단어 수 9999 | 손실 0.011812 | perplexity 1.011882
# | 에포크 636 | 단어 수 9999 | 손실 0.012392 | perplexity 1.012469
# | 에포크 637 | 단어 수 9999 | 손실 0.010558 | perplexity 1.010614
# | 에포크 638 | 단어 수 9999 | 손실 0.011386 | perplexity 1.011451
# | 에포크 639 | 단어 수 9999 | 손실 0.008812 | perplexity 1.008851
# | 에포크 640 | 단어 수 9999 | 손실 0.006714 | perplexity 1.006736
# | 에포크 641 | 단어 수 9999 | 손실 0.007329 | perplexity 1.007356
# | 에포크 642 | 단어 수 9999 | 손실 0.005771 | perplexity 1.005787
# | 에포크 643 | 단어 수 9999 | 손실 0.004798 | perplexity 1.004810
# | 에포크 644 | 단어 수 9999 | 손실 0.006329 | perplexity 1.006350
# | 에포크 645 | 단어 수 9999 | 손실 0.010377 | perplexity 1.010431
# | 에포크 646 | 단어 수 9999 | 손실 0.018286 | perplexity 1.018454
# | 에포크 647 | 단어 수 9999 | 손실 0.056650 | perplexity 1.058285
# | 에포크 648 | 단어 수 9999 | 손실 0.065213 | perplexity 1.067386
# | 에포크 649 | 단어 수 9999 | 손실 0.050148 | perplexity 1.051426
# | 에포크 650 | 단어 수 9999 | 손실 0.030198 | perplexity 1.030659
# | 에포크 651 | 단어 수 9999 | 손실 0.014901 | perplexity 1.015013
# | 에포크 652 | 단어 수 9999 | 손실 0.012876 | perplexity 1.012959
# | 에포크 653 | 단어 수 9999 | 손실 0.011584 | perplexity 1.011651
# | 에포크 654 | 단어 수 9999 | 손실 0.011128 | perplexity 1.011190
# | 에포크 655 | 단어 수 9999 | 손실 0.009796 | perplexity 1.009844
# | 에포크 656 | 단어 수 9999 | 손실 0.011377 | perplexity 1.011442
# | 에포크 657 | 단어 수 9999 | 손실 0.011073 | perplexity 1.011134
# | 에포크 658 | 단어 수 9999 | 손실 0.009203 | perplexity 1.009245
# | 에포크 659 | 단어 수 9999 | 손실 0.008067 | perplexity 1.008100
# | 에포크 660 | 단어 수 9999 | 손실 0.014268 | perplexity 1.014370
# | 에포크 661 | 단어 수 9999 | 손실 0.021506 | perplexity 1.021739
# | 에포크 662 | 단어 수 9999 | 손실 0.021661 | perplexity 1.021897
# | 에포크 663 | 단어 수 9999 | 손실 0.023173 | perplexity 1.023443
# | 에포크 664 | 단어 수 9999 | 손실 0.024215 | perplexity 1.024511
# | 에포크 665 | 단어 수 9999 | 손실 0.021384 | perplexity 1.021614
# | 에포크 666 | 단어 수 9999 | 손실 0.016682 | perplexity 1.016822
# | 에포크 667 | 단어 수 9999 | 손실 0.019701 | perplexity 1.019896
# | 에포크 668 | 단어 수 9999 | 손실 0.013975 | perplexity 1.014073
# | 에포크 669 | 단어 수 9999 | 손실 0.010518 | perplexity 1.010573
# | 에포크 670 | 단어 수 9999 | 손실 0.008820 | perplexity 1.008859
# | 에포크 671 | 단어 수 9999 | 손실 0.010759 | perplexity 1.010817
# | 에포크 672 | 단어 수 9999 | 손실 0.011131 | perplexity 1.011193
# | 에포크 673 | 단어 수 9999 | 손실 0.012884 | perplexity 1.012967
# | 에포크 674 | 단어 수 9999 | 손실 0.008592 | perplexity 1.008629
# | 에포크 675 | 단어 수 9999 | 손실 0.008959 | perplexity 1.009000
# | 에포크 676 | 단어 수 9999 | 손실 0.007160 | perplexity 1.007185
# | 에포크 677 | 단어 수 9999 | 손실 0.007288 | perplexity 1.007315
# | 에포크 678 | 단어 수 9999 | 손실 0.012310 | perplexity 1.012386
# | 에포크 679 | 단어 수 9999 | 손실 0.028065 | perplexity 1.028463
# | 에포크 680 | 단어 수 9999 | 손실 0.046312 | perplexity 1.047401
# | 에포크 681 | 단어 수 9999 | 손실 0.049195 | perplexity 1.050425
# | 에포크 682 | 단어 수 9999 | 손실 0.034153 | perplexity 1.034743
# | 에포크 683 | 단어 수 9999 | 손실 0.020525 | perplexity 1.020737
# | 에포크 684 | 단어 수 9999 | 손실 0.020618 | perplexity 1.020832
# | 에포크 685 | 단어 수 9999 | 손실 0.018137 | perplexity 1.018302
# | 에포크 686 | 단어 수 9999 | 손실 0.015607 | perplexity 1.015729
# | 에포크 687 | 단어 수 9999 | 손실 0.011981 | perplexity 1.012053
# | 에포크 688 | 단어 수 9999 | 손실 0.007310 | perplexity 1.007337
# | 에포크 689 | 단어 수 9999 | 손실 0.005773 | perplexity 1.005790
# | 에포크 690 | 단어 수 9999 | 손실 0.005614 | perplexity 1.005630
# | 에포크 691 | 단어 수 9999 | 손실 0.004502 | perplexity 1.004512
# | 에포크 692 | 단어 수 9999 | 손실 0.004588 | perplexity 1.004599
# | 에포크 693 | 단어 수 9999 | 손실 0.004783 | perplexity 1.004795
# | 에포크 694 | 단어 수 9999 | 손실 0.004391 | perplexity 1.004400
# | 에포크 695 | 단어 수 9999 | 손실 0.004278 | perplexity 1.004287
# | 에포크 696 | 단어 수 9999 | 손실 0.006025 | perplexity 1.006043
# | 에포크 697 | 단어 수 9999 | 손실 0.012078 | perplexity 1.012151
# | 에포크 698 | 단어 수 9999 | 손실 0.035056 | perplexity 1.035678
# | 에포크 699 | 단어 수 9999 | 손실 0.056127 | perplexity 1.057732
# | 에포크 700 | 단어 수 9999 | 손실 0.057410 | perplexity 1.059090
# | 에포크 701 | 단어 수 9999 | 손실 0.042015 | perplexity 1.042910
# | 에포크 702 | 단어 수 9999 | 손실 0.025246 | perplexity 1.025567
# | 에포크 703 | 단어 수 9999 | 손실 0.014105 | perplexity 1.014205
# | 에포크 704 | 단어 수 9999 | 손실 0.008643 | perplexity 1.008681
# | 에포크 705 | 단어 수 9999 | 손실 0.007117 | perplexity 1.007142
# | 에포크 706 | 단어 수 9999 | 손실 0.006305 | perplexity 1.006325
# | 에포크 707 | 단어 수 9999 | 손실 0.007437 | perplexity 1.007465
# | 에포크 708 | 단어 수 9999 | 손실 0.008750 | perplexity 1.008789
# | 에포크 709 | 단어 수 9999 | 손실 0.012529 | perplexity 1.012608
# | 에포크 710 | 단어 수 9999 | 손실 0.008411 | perplexity 1.008446
# | 에포크 711 | 단어 수 9999 | 손실 0.014480 | perplexity 1.014585
# | 에포크 712 | 단어 수 9999 | 손실 0.017938 | perplexity 1.018100
# | 에포크 713 | 단어 수 9999 | 손실 0.014967 | perplexity 1.015080
# | 에포크 714 | 단어 수 9999 | 손실 0.013693 | perplexity 1.013787
# | 에포크 715 | 단어 수 9999 | 손실 0.010384 | perplexity 1.010438
# | 에포크 716 | 단어 수 9999 | 손실 0.007831 | perplexity 1.007862
# | 에포크 717 | 단어 수 9999 | 손실 0.007931 | perplexity 1.007963
# | 에포크 718 | 단어 수 9999 | 손실 0.006721 | perplexity 1.006744
# | 에포크 719 | 단어 수 9999 | 손실 0.009065 | perplexity 1.009106
# | 에포크 720 | 단어 수 9999 | 손실 0.013899 | perplexity 1.013996
# | 에포크 721 | 단어 수 9999 | 손실 0.041847 | perplexity 1.042735
# | 에포크 722 | 단어 수 9999 | 손실 0.051726 | perplexity 1.053087
# | 에포크 723 | 단어 수 9999 | 손실 0.044089 | perplexity 1.045075
# | 에포크 724 | 단어 수 9999 | 손실 0.030462 | perplexity 1.030931
# | 에포크 725 | 단어 수 9999 | 손실 0.018798 | perplexity 1.018975
# | 에포크 726 | 단어 수 9999 | 손실 0.011757 | perplexity 1.011827
# | 에포크 727 | 단어 수 9999 | 손실 0.007699 | perplexity 1.007729
# | 에포크 728 | 단어 수 9999 | 손실 0.005090 | perplexity 1.005103
# | 에포크 729 | 단어 수 9999 | 손실 0.004505 | perplexity 1.004515
# | 에포크 730 | 단어 수 9999 | 손실 0.003809 | perplexity 1.003816
# | 에포크 731 | 단어 수 9999 | 손실 0.003364 | perplexity 1.003370
# | 에포크 732 | 단어 수 9999 | 손실 0.003041 | perplexity 1.003046
# | 에포크 733 | 단어 수 9999 | 손실 0.002731 | perplexity 1.002735
# | 에포크 734 | 단어 수 9999 | 손실 0.002776 | perplexity 1.002780
# | 에포크 735 | 단어 수 9999 | 손실 0.002751 | perplexity 1.002755
# | 에포크 736 | 단어 수 9999 | 손실 0.002795 | perplexity 1.002798
# | 에포크 737 | 단어 수 9999 | 손실 0.002755 | perplexity 1.002759
# | 에포크 738 | 단어 수 9999 | 손실 0.003048 | perplexity 1.003053
# | 에포크 739 | 단어 수 9999 | 손실 0.003127 | perplexity 1.003132
# | 에포크 740 | 단어 수 9999 | 손실 0.010230 | perplexity 1.010283
# | 에포크 741 | 단어 수 9999 | 손실 0.092579 | perplexity 1.097000
# | 에포크 742 | 단어 수 9999 | 손실 0.086770 | perplexity 1.090646
# | 에포크 743 | 단어 수 9999 | 손실 0.045897 | perplexity 1.046966
# | 에포크 744 | 단어 수 9999 | 손실 0.025897 | perplexity 1.026236
# | 에포크 745 | 단어 수 9999 | 손실 0.013195 | perplexity 1.013282
# | 에포크 746 | 단어 수 9999 | 손실 0.008902 | perplexity 1.008941
# | 에포크 747 | 단어 수 9999 | 손실 0.006100 | perplexity 1.006119
# | 에포크 748 | 단어 수 9999 | 손실 0.004938 | perplexity 1.004950
# | 에포크 749 | 단어 수 9999 | 손실 0.004663 | perplexity 1.004674
# | 에포크 750 | 단어 수 9999 | 손실 0.005344 | perplexity 1.005358
# | 에포크 751 | 단어 수 9999 | 손실 0.004042 | perplexity 1.004050
# | 에포크 752 | 단어 수 9999 | 손실 0.003384 | perplexity 1.003389
# | 에포크 753 | 단어 수 9999 | 손실 0.003244 | perplexity 1.003249
# | 에포크 754 | 단어 수 9999 | 손실 0.003424 | perplexity 1.003430
# | 에포크 755 | 단어 수 9999 | 손실 0.005276 | perplexity 1.005290
# | 에포크 756 | 단어 수 9999 | 손실 0.005297 | perplexity 1.005311
# | 에포크 757 | 단어 수 9999 | 손실 0.005950 | perplexity 1.005968
# | 에포크 758 | 단어 수 9999 | 손실 0.012270 | perplexity 1.012346
# | 에포크 759 | 단어 수 9999 | 손실 0.059267 | perplexity 1.061058
# | 에포크 760 | 단어 수 9999 | 손실 0.076935 | perplexity 1.079972
# | 에포크 761 | 단어 수 9999 | 손실 0.046708 | perplexity 1.047816
# | 에포크 762 | 단어 수 9999 | 손실 0.029200 | perplexity 1.029631
# | 에포크 763 | 단어 수 9999 | 손실 0.021840 | perplexity 1.022080
# | 에포크 764 | 단어 수 9999 | 손실 0.016573 | perplexity 1.016711
# | 에포크 765 | 단어 수 9999 | 손실 0.012491 | perplexity 1.012569
# | 에포크 766 | 단어 수 9999 | 손실 0.010596 | perplexity 1.010652
# | 에포크 767 | 단어 수 9999 | 손실 0.012176 | perplexity 1.012250
# | 에포크 768 | 단어 수 9999 | 손실 0.006399 | perplexity 1.006419
# | 에포크 769 | 단어 수 9999 | 손실 0.005335 | perplexity 1.005350
# | 에포크 770 | 단어 수 9999 | 손실 0.004357 | perplexity 1.004366
# | 에포크 771 | 단어 수 9999 | 손실 0.003096 | perplexity 1.003101
# | 에포크 772 | 단어 수 9999 | 손실 0.003048 | perplexity 1.003053
# | 에포크 773 | 단어 수 9999 | 손실 0.002965 | perplexity 1.002969
# | 에포크 774 | 단어 수 9999 | 손실 0.003332 | perplexity 1.003338
# | 에포크 775 | 단어 수 9999 | 손실 0.002695 | perplexity 1.002698
# | 에포크 776 | 단어 수 9999 | 손실 0.002998 | perplexity 1.003003
# | 에포크 777 | 단어 수 9999 | 손실 0.002532 | perplexity 1.002535
# | 에포크 778 | 단어 수 9999 | 손실 0.002545 | perplexity 1.002548
# | 에포크 779 | 단어 수 9999 | 손실 0.003759 | perplexity 1.003766
# | 에포크 780 | 단어 수 9999 | 손실 0.005308 | perplexity 1.005322
# | 에포크 781 | 단어 수 9999 | 손실 0.070964 | perplexity 1.073542
# | 에포크 782 | 단어 수 9999 | 손실 0.108651 | perplexity 1.114774
# | 에포크 783 | 단어 수 9999 | 손실 0.061151 | perplexity 1.063060
# | 에포크 784 | 단어 수 9999 | 손실 0.029530 | perplexity 1.029970
# | 에포크 785 | 단어 수 9999 | 손실 0.024176 | perplexity 1.024470
# | 에포크 786 | 단어 수 9999 | 손실 0.017301 | perplexity 1.017451
# | 에포크 787 | 단어 수 9999 | 손실 0.012633 | perplexity 1.012714
# | 에포크 788 | 단어 수 9999 | 손실 0.007263 | perplexity 1.007290
# | 에포크 789 | 단어 수 9999 | 손실 0.005170 | perplexity 1.005183
# | 에포크 790 | 단어 수 9999 | 손실 0.004047 | perplexity 1.004055
# | 에포크 791 | 단어 수 9999 | 손실 0.003581 | perplexity 1.003587
# | 에포크 792 | 단어 수 9999 | 손실 0.003421 | perplexity 1.003427
# | 에포크 793 | 단어 수 9999 | 손실 0.004705 | perplexity 1.004716
# | 에포크 794 | 단어 수 9999 | 손실 0.005492 | perplexity 1.005507
# | 에포크 795 | 단어 수 9999 | 손실 0.011175 | perplexity 1.011238
# | 에포크 796 | 단어 수 9999 | 손실 0.024419 | perplexity 1.024719
# | 에포크 797 | 단어 수 9999 | 손실 0.038542 | perplexity 1.039295
# | 에포크 798 | 단어 수 9999 | 손실 0.043198 | perplexity 1.044145
# | 에포크 799 | 단어 수 9999 | 손실 0.034764 | perplexity 1.035376
# | 에포크 800 | 단어 수 9999 | 손실 0.022755 | perplexity 1.023016
# | 에포크 801 | 단어 수 9999 | 손실 0.017181 | perplexity 1.017329
# | 에포크 802 | 단어 수 9999 | 손실 0.013875 | perplexity 1.013972
# | 에포크 803 | 단어 수 9999 | 손실 0.010153 | perplexity 1.010205
# | 에포크 804 | 단어 수 9999 | 손실 0.008769 | perplexity 1.008808
# | 에포크 805 | 단어 수 9999 | 손실 0.008526 | perplexity 1.008562
# | 에포크 806 | 단어 수 9999 | 손실 0.007336 | perplexity 1.007363
# | 에포크 807 | 단어 수 9999 | 손실 0.004610 | perplexity 1.004621
# | 에포크 808 | 단어 수 9999 | 손실 0.003830 | perplexity 1.003838
# | 에포크 809 | 단어 수 9999 | 손실 0.003877 | perplexity 1.003884
# | 에포크 810 | 단어 수 9999 | 손실 0.004360 | perplexity 1.004370
# | 에포크 811 | 단어 수 9999 | 손실 0.003134 | perplexity 1.003139
# | 에포크 812 | 단어 수 9999 | 손실 0.004081 | perplexity 1.004089
# | 에포크 813 | 단어 수 9999 | 손실 0.007876 | perplexity 1.007907
# | 에포크 814 | 단어 수 9999 | 손실 0.036538 | perplexity 1.037214
# | 에포크 815 | 단어 수 9999 | 손실 0.069108 | perplexity 1.071551
# | 에포크 816 | 단어 수 9999 | 손실 0.066895 | perplexity 1.069183
# | 에포크 817 | 단어 수 9999 | 손실 0.040093 | perplexity 1.040908
# | 에포크 818 | 단어 수 9999 | 손실 0.024606 | perplexity 1.024911
# | 에포크 819 | 단어 수 9999 | 손실 0.017574 | perplexity 1.017729
# | 에포크 820 | 단어 수 9999 | 손실 0.011139 | perplexity 1.011201
# | 에포크 821 | 단어 수 9999 | 손실 0.008032 | perplexity 1.008064
# | 에포크 822 | 단어 수 9999 | 손실 0.006364 | perplexity 1.006385
# | 에포크 823 | 단어 수 9999 | 손실 0.005174 | perplexity 1.005188
# | 에포크 824 | 단어 수 9999 | 손실 0.004535 | perplexity 1.004545
# | 에포크 825 | 단어 수 9999 | 손실 0.004356 | perplexity 1.004366
# | 에포크 826 | 단어 수 9999 | 손실 0.003572 | perplexity 1.003578
# | 에포크 827 | 단어 수 9999 | 손실 0.003874 | perplexity 1.003882
# | 에포크 828 | 단어 수 9999 | 손실 0.004293 | perplexity 1.004302
# | 에포크 829 | 단어 수 9999 | 손실 0.004188 | perplexity 1.004196
# | 에포크 830 | 단어 수 9999 | 손실 0.006463 | perplexity 1.006484
# | 에포크 831 | 단어 수 9999 | 손실 0.013581 | perplexity 1.013674
# | 에포크 832 | 단어 수 9999 | 손실 0.048383 | perplexity 1.049573
# | 에포크 833 | 단어 수 9999 | 손실 0.073395 | perplexity 1.076156
# | 에포크 834 | 단어 수 9999 | 손실 0.050469 | perplexity 1.051764
# | 에포크 835 | 단어 수 9999 | 손실 0.032571 | perplexity 1.033107
# | 에포크 836 | 단어 수 9999 | 손실 0.015426 | perplexity 1.015545
# | 에포크 837 | 단어 수 9999 | 손실 0.012374 | perplexity 1.012451
# | 에포크 838 | 단어 수 9999 | 손실 0.009666 | perplexity 1.009713
# | 에포크 839 | 단어 수 9999 | 손실 0.007684 | perplexity 1.007714
# | 에포크 840 | 단어 수 9999 | 손실 0.006408 | perplexity 1.006429
# | 에포크 841 | 단어 수 9999 | 손실 0.006197 | perplexity 1.006217
# | 에포크 842 | 단어 수 9999 | 손실 0.010269 | perplexity 1.010322
# | 에포크 843 | 단어 수 9999 | 손실 0.011744 | perplexity 1.011813
# | 에포크 844 | 단어 수 9999 | 손실 0.011588 | perplexity 1.011655
# | 에포크 845 | 단어 수 9999 | 손실 0.012477 | perplexity 1.012555
# | 에포크 846 | 단어 수 9999 | 손실 0.008731 | perplexity 1.008770
# | 에포크 847 | 단어 수 9999 | 손실 0.007803 | perplexity 1.007834
# | 에포크 848 | 단어 수 9999 | 손실 0.008333 | perplexity 1.008368
# | 에포크 849 | 단어 수 9999 | 손실 0.014538 | perplexity 1.014644
# | 에포크 850 | 단어 수 9999 | 손실 0.023258 | perplexity 1.023530
# | 에포크 851 | 단어 수 9999 | 손실 0.031743 | perplexity 1.032252
# | 에포크 852 | 단어 수 9999 | 손실 0.029618 | perplexity 1.030060
# | 에포크 853 | 단어 수 9999 | 손실 0.028888 | perplexity 1.029309
# | 에포크 854 | 단어 수 9999 | 손실 0.024396 | perplexity 1.024696
# | 에포크 855 | 단어 수 9999 | 손실 0.016210 | perplexity 1.016342
# | 에포크 856 | 단어 수 9999 | 손실 0.012562 | perplexity 1.012642
# | 에포크 857 | 단어 수 9999 | 손실 0.008630 | perplexity 1.008668
# | 에포크 858 | 단어 수 9999 | 손실 0.006711 | perplexity 1.006733
# | 에포크 859 | 단어 수 9999 | 손실 0.005821 | perplexity 1.005838
# | 에포크 860 | 단어 수 9999 | 손실 0.004824 | perplexity 1.004836
# | 에포크 861 | 단어 수 9999 | 손실 0.006042 | perplexity 1.006060
# | 에포크 862 | 단어 수 9999 | 손실 0.005062 | perplexity 1.005075
# | 에포크 863 | 단어 수 9999 | 손실 0.008276 | perplexity 1.008310
# | 에포크 864 | 단어 수 9999 | 손실 0.009701 | perplexity 1.009748
# | 에포크 865 | 단어 수 9999 | 손실 0.024446 | perplexity 1.024747
# | 에포크 866 | 단어 수 9999 | 손실 0.042264 | perplexity 1.043169
# | 에포크 867 | 단어 수 9999 | 손실 0.034398 | perplexity 1.034997
# | 에포크 868 | 단어 수 9999 | 손실 0.030674 | perplexity 1.031149
# | 에포크 869 | 단어 수 9999 | 손실 0.023985 | perplexity 1.024275
# | 에포크 870 | 단어 수 9999 | 손실 0.019408 | perplexity 1.019598
# | 에포크 871 | 단어 수 9999 | 손실 0.012010 | perplexity 1.012082
# | 에포크 872 | 단어 수 9999 | 손실 0.011522 | perplexity 1.011589
# | 에포크 873 | 단어 수 9999 | 손실 0.011520 | perplexity 1.011587
# | 에포크 874 | 단어 수 9999 | 손실 0.011690 | perplexity 1.011758
# | 에포크 875 | 단어 수 9999 | 손실 0.014584 | perplexity 1.014691
# | 에포크 876 | 단어 수 9999 | 손실 0.012824 | perplexity 1.012907
# | 에포크 877 | 단어 수 9999 | 손실 0.013141 | perplexity 1.013227
# | 에포크 878 | 단어 수 9999 | 손실 0.012494 | perplexity 1.012572
# | 에포크 879 | 단어 수 9999 | 손실 0.010391 | perplexity 1.010445
# | 에포크 880 | 단어 수 9999 | 손실 0.012108 | perplexity 1.012182
# | 에포크 881 | 단어 수 9999 | 손실 0.013461 | perplexity 1.013552
# | 에포크 882 | 단어 수 9999 | 손실 0.012022 | perplexity 1.012094
# | 에포크 883 | 단어 수 9999 | 손실 0.013887 | perplexity 1.013984
# | 에포크 884 | 단어 수 9999 | 손실 0.016425 | perplexity 1.016561
# | 에포크 885 | 단어 수 9999 | 손실 0.026036 | perplexity 1.026378
# | 에포크 886 | 단어 수 9999 | 손실 0.033851 | perplexity 1.034431
# | 에포크 887 | 단어 수 9999 | 손실 0.029831 | perplexity 1.030281
# | 에포크 888 | 단어 수 9999 | 손실 0.022852 | perplexity 1.023116
# | 에포크 889 | 단어 수 9999 | 손실 0.013622 | perplexity 1.013715
# | 에포크 890 | 단어 수 9999 | 손실 0.008497 | perplexity 1.008533
# | 에포크 891 | 단어 수 9999 | 손실 0.006486 | perplexity 1.006507
# | 에포크 892 | 단어 수 9999 | 손실 0.005191 | perplexity 1.005205
# | 에포크 893 | 단어 수 9999 | 손실 0.005130 | perplexity 1.005144
# | 에포크 894 | 단어 수 9999 | 손실 0.004468 | perplexity 1.004478
# | 에포크 895 | 단어 수 9999 | 손실 0.004110 | perplexity 1.004118
# | 에포크 896 | 단어 수 9999 | 손실 0.003442 | perplexity 1.003448
# | 에포크 897 | 단어 수 9999 | 손실 0.003176 | perplexity 1.003181
# | 에포크 898 | 단어 수 9999 | 손실 0.003058 | perplexity 1.003063
# | 에포크 899 | 단어 수 9999 | 손실 0.002926 | perplexity 1.002930
# | 에포크 900 | 단어 수 9999 | 손실 0.003369 | perplexity 1.003375
# | 에포크 901 | 단어 수 9999 | 손실 0.004063 | perplexity 1.004071
# | 에포크 902 | 단어 수 9999 | 손실 0.004271 | perplexity 1.004280
# | 에포크 903 | 단어 수 9999 | 손실 0.006599 | perplexity 1.006621
# | 에포크 904 | 단어 수 9999 | 손실 0.066481 | perplexity 1.068741
# | 에포크 905 | 단어 수 9999 | 손실 0.112185 | perplexity 1.118719
# | 에포크 906 | 단어 수 9999 | 손실 0.052226 | perplexity 1.053613
# | 에포크 907 | 단어 수 9999 | 손실 0.032358 | perplexity 1.032888
# | 에포크 908 | 단어 수 9999 | 손실 0.019924 | perplexity 1.020124
# | 에포크 909 | 단어 수 9999 | 손실 0.015403 | perplexity 1.015523
# | 에포크 910 | 단어 수 9999 | 손실 0.009409 | perplexity 1.009453
# | 에포크 911 | 단어 수 9999 | 손실 0.006297 | perplexity 1.006317
# | 에포크 912 | 단어 수 9999 | 손실 0.005755 | perplexity 1.005772
# | 에포크 913 | 단어 수 9999 | 손실 0.005434 | perplexity 1.005448
# | 에포크 914 | 단어 수 9999 | 손실 0.004761 | perplexity 1.004772
# | 에포크 915 | 단어 수 9999 | 손실 0.004552 | perplexity 1.004563
# | 에포크 916 | 단어 수 9999 | 손실 0.004802 | perplexity 1.004814
# | 에포크 917 | 단어 수 9999 | 손실 0.004384 | perplexity 1.004394
# | 에포크 918 | 단어 수 9999 | 손실 0.004454 | perplexity 1.004464
# | 에포크 919 | 단어 수 9999 | 손실 0.004031 | perplexity 1.004040
# | 에포크 920 | 단어 수 9999 | 손실 0.006305 | perplexity 1.006325
# | 에포크 921 | 단어 수 9999 | 손실 0.013730 | perplexity 1.013824
# | 에포크 922 | 단어 수 9999 | 손실 0.052915 | perplexity 1.054340
# | 에포크 923 | 단어 수 9999 | 손실 0.066693 | perplexity 1.068967
# | 에포크 924 | 단어 수 9999 | 손실 0.050506 | perplexity 1.051803
# | 에포크 925 | 단어 수 9999 | 손실 0.035639 | perplexity 1.036282
# | 에포크 926 | 단어 수 9999 | 손실 0.023925 | perplexity 1.024214
# | 에포크 927 | 단어 수 9999 | 손실 0.016512 | perplexity 1.016649
# | 에포크 928 | 단어 수 9999 | 손실 0.009294 | perplexity 1.009338
# | 에포크 929 | 단어 수 9999 | 손실 0.007889 | perplexity 1.007921
# | 에포크 930 | 단어 수 9999 | 손실 0.007184 | perplexity 1.007210
# | 에포크 931 | 단어 수 9999 | 손실 0.005113 | perplexity 1.005126
# | 에포크 932 | 단어 수 9999 | 손실 0.005266 | perplexity 1.005280
# | 에포크 933 | 단어 수 9999 | 손실 0.003583 | perplexity 1.003589
# | 에포크 934 | 단어 수 9999 | 손실 0.003553 | perplexity 1.003559
# | 에포크 935 | 단어 수 9999 | 손실 0.003033 | perplexity 1.003038
# | 에포크 936 | 단어 수 9999 | 손실 0.003463 | perplexity 1.003469
# | 에포크 937 | 단어 수 9999 | 손실 0.005995 | perplexity 1.006013
# | 에포크 938 | 단어 수 9999 | 손실 0.005980 | perplexity 1.005998
# | 에포크 939 | 단어 수 9999 | 손실 0.011735 | perplexity 1.011804
# | 에포크 940 | 단어 수 9999 | 손실 0.037918 | perplexity 1.038646
# | 에포크 941 | 단어 수 9999 | 손실 0.072421 | perplexity 1.075108
# | 에포크 942 | 단어 수 9999 | 손실 0.063359 | perplexity 1.065409
# | 에포크 943 | 단어 수 9999 | 손실 0.033296 | perplexity 1.033856
# | 에포크 944 | 단어 수 9999 | 손실 0.022003 | perplexity 1.022247
# | 에포크 945 | 단어 수 9999 | 손실 0.016240 | perplexity 1.016373
# | 에포크 946 | 단어 수 9999 | 손실 0.011698 | perplexity 1.011766
# | 에포크 947 | 단어 수 9999 | 손실 0.009153 | perplexity 1.009195
# | 에포크 948 | 단어 수 9999 | 손실 0.006944 | perplexity 1.006968
# | 에포크 949 | 단어 수 9999 | 손실 0.006231 | perplexity 1.006250
# | 에포크 950 | 단어 수 9999 | 손실 0.006412 | perplexity 1.006433
# | 에포크 951 | 단어 수 9999 | 손실 0.004694 | perplexity 1.004705
# | 에포크 952 | 단어 수 9999 | 손실 0.005329 | perplexity 1.005343
# | 에포크 953 | 단어 수 9999 | 손실 0.006192 | perplexity 1.006212
# | 에포크 954 | 단어 수 9999 | 손실 0.012714 | perplexity 1.012795
# | 에포크 955 | 단어 수 9999 | 손실 0.023255 | perplexity 1.023527
# | 에포크 956 | 단어 수 9999 | 손실 0.026455 | perplexity 1.026808
# | 에포크 957 | 단어 수 9999 | 손실 0.030544 | perplexity 1.031016
# | 에포크 958 | 단어 수 9999 | 손실 0.028636 | perplexity 1.029050
# | 에포크 959 | 단어 수 9999 | 손실 0.026724 | perplexity 1.027085
# | 에포크 960 | 단어 수 9999 | 손실 0.021465 | perplexity 1.021697
# | 에포크 961 | 단어 수 9999 | 손실 0.016452 | perplexity 1.016588
# | 에포크 962 | 단어 수 9999 | 손실 0.015383 | perplexity 1.015502
# | 에포크 963 | 단어 수 9999 | 손실 0.013516 | perplexity 1.013608
# | 에포크 964 | 단어 수 9999 | 손실 0.006536 | perplexity 1.006558
# | 에포크 965 | 단어 수 9999 | 손실 0.008640 | perplexity 1.008677
# | 에포크 966 | 단어 수 9999 | 손실 0.008434 | perplexity 1.008470
# | 에포크 967 | 단어 수 9999 | 손실 0.007164 | perplexity 1.007189
# | 에포크 968 | 단어 수 9999 | 손실 0.006209 | perplexity 1.006229
# | 에포크 969 | 단어 수 9999 | 손실 0.004202 | perplexity 1.004211
# | 에포크 970 | 단어 수 9999 | 손실 0.004434 | perplexity 1.004443
# | 에포크 971 | 단어 수 9999 | 손실 0.004041 | perplexity 1.004049
# | 에포크 972 | 단어 수 9999 | 손실 0.003335 | perplexity 1.003340
# | 에포크 973 | 단어 수 9999 | 손실 0.003140 | perplexity 1.003145
# | 에포크 974 | 단어 수 9999 | 손실 0.004022 | perplexity 1.004030
# | 에포크 975 | 단어 수 9999 | 손실 0.003192 | perplexity 1.003197
# | 에포크 976 | 단어 수 9999 | 손실 0.017971 | perplexity 1.018133
# | 에포크 977 | 단어 수 9999 | 손실 0.088588 | perplexity 1.092630
# | 에포크 978 | 단어 수 9999 | 손실 0.068942 | perplexity 1.071374
# | 에포크 979 | 단어 수 9999 | 손실 0.048544 | perplexity 1.049742
# | 에포크 980 | 단어 수 9999 | 손실 0.028922 | perplexity 1.029345
# | 에포크 981 | 단어 수 9999 | 손실 0.016505 | perplexity 1.016642
# | 에포크 982 | 단어 수 9999 | 손실 0.010674 | perplexity 1.010732
# | 에포크 983 | 단어 수 9999 | 손실 0.009704 | perplexity 1.009751
# | 에포크 984 | 단어 수 9999 | 손실 0.006355 | perplexity 1.006375
# | 에포크 985 | 단어 수 9999 | 손실 0.004907 | perplexity 1.004919
# | 에포크 986 | 단어 수 9999 | 손실 0.005676 | perplexity 1.005692
# | 에포크 987 | 단어 수 9999 | 손실 0.005209 | perplexity 1.005223
# | 에포크 988 | 단어 수 9999 | 손실 0.004755 | perplexity 1.004767
# | 에포크 989 | 단어 수 9999 | 손실 0.004897 | perplexity 1.004909
# | 에포크 990 | 단어 수 9999 | 손실 0.004948 | perplexity 1.004961
# | 에포크 991 | 단어 수 9999 | 손실 0.004437 | perplexity 1.004447
# | 에포크 992 | 단어 수 9999 | 손실 0.007175 | perplexity 1.007200
# | 에포크 993 | 단어 수 9999 | 손실 0.020718 | perplexity 1.020934
# | 에포크 994 | 단어 수 9999 | 손실 0.057298 | perplexity 1.058972
# | 에포크 995 | 단어 수 9999 | 손실 0.061275 | perplexity 1.063192
# | 에포크 996 | 단어 수 9999 | 손실 0.038284 | perplexity 1.039026
# | 에포크 997 | 단어 수 9999 | 손실 0.027139 | perplexity 1.027511
# | 에포크 998 | 단어 수 9999 | 손실 0.020048 | perplexity 1.020250
# | 에포크 999 | 단어 수 9999 | 손실 0.014619 | perplexity 1.014727
# | 에포크 1000 | 단어 수 9999 | 손실 0.011485 | perplexity 1.011551
